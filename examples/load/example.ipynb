# %% [markdown]
# # GraphToolbox - Load Example

# %% [markdown]
# This notebook was succesfully tested with Python 3.11.9.

# %% [markdown]
# ## Importing libraries

# %% [markdown]
# Importing all libraries should take a minute or two.

# %%
# General libraries
import gc
import torch
from torch_geometric.nn.conv import *
from torch_geometric.nn.models import *
from torch_geometric import seed_everything

# GraphToolbox
from graphtoolbox.data import *
from graphtoolbox.models import *
from graphtoolbox.optim import *
from graphtoolbox.training import *
from graphtoolbox.utils import *
from graphtoolbox.aggregation import Aggregation

# Autoreload
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CUDA or not CUDA ?

# %%
print('CUDA'*(torch.cuda.is_available())+(1-torch.cuda.is_available())*'not CUDA')
# Out:
# not CUDA

# %% [markdown]
# ## Instantiating graph objects

# %% [markdown]
# There are two graph objects in the following cell:
#
# - a **DataClass** object, which is always defined by three arguments: `path_train` which is the path to the training dataset, `path_test` which is the path to the testing dataset, and `folder_config` which is the folder of your config file. There are additional keyword arguments if you want to specify a validation set. A DataClass object allows to manipulate the dataframes easily.
#
# - a **GraphDataset** object, which is always defined by two arguments: `data` which is an instance of DataClass, `period` which specifies if it is a train., val. or test. dataset. If the dataset is for validation or test, then you will need to specify scalers: `scalers_feat` to scale the features, and `scalers_target` to scale the target. There are additional keyword arguments that you can find in the documentation. A GraphDataset object allows to manipulate the data as graph objects in the PyG format.

# %%
import pandas as pd
import numpy as np

data_kwargs = {
    'node_var': 'Region',
    'features_to_lag': {'load': (1, 48), 'temp': (-47, -1)},
    'dummies': ['Instant', 'RegionInt', 'JourSemaine', 'DayType', 'offset'],
    'day_inf_train': '2015-01-01',
    'day_sup_train': '2018-01-01',
    'day_inf_val': '2018-01-01',
    'day_sup_val': '2018-12-31',
    'day_inf_test': '2019-01-01',
    'day_sup_test': '2019-12-31',
    # Non-linear temperature features 
    'computed_features': {
        'heat_deg':  lambda df: (15 - df['temp']).clip(lower=0),   # heating degrees (below 15°C)
        'cool_deg':  lambda df: (df['temp'] - 15).clip(lower=0),   # cooling degrees (above 15°C)
        'temp_sq':   lambda df: df['temp'] ** 2,                   # quadratic term for extremes
        'is_summer': lambda df: (pd.to_datetime(df['date']).dt.month == 7).astype(float) + (pd.to_datetime(df['date']).dt.month == 8).astype(float),  # July-August dummy
    },
}

dataset_kwargs = {
    'batch_size': 32,
    'adj_matrix': 'dtw',
    'features_base': ['temp', 'nebu', 'wind', 'tempMax', 'tempMin', 'Posan', 'Instant', 'RegionInt', 'JourSemaine', 'JourFerie', 'offset', 'DayType', 'Weekend', 'temp_liss_fort', 'temp_liss_faible',
                        'heat_deg', 'cool_deg', 'temp_sq', 'is_summer'] + [f'load_l{t}' for t in range(1, 48+1)] + [f'temp_l{t}' for t in range(-47, -1+1)],
    'target_base': 'load',
}

out_channels = 48
data = DataClass(path_train='./train.csv', 
                 path_test='./test.csv', 
                 data_kwargs=data_kwargs,
                 folder_config='.')

graph_dataset_train = GraphDataset(data=data, period='train', 
                                   graph_folder='../graph_representations',
                                   dataset_kwargs=dataset_kwargs,
                                   out_channels=out_channels)
graph_dataset_val = GraphDataset(data=data, period='val', 
                                 scalers_feat=graph_dataset_train.scalers_feat, 
                                 scalers_target=graph_dataset_train.scalers_target,
                                 graph_folder='../graph_representations',
                                 dataset_kwargs=dataset_kwargs,
                                 out_channels=out_channels)
graph_dataset_test = GraphDataset(data=data, period='test',
                                  scalers_feat=graph_dataset_train.scalers_feat, 
                                  scalers_target=graph_dataset_train.scalers_target,
                                  graph_folder='../graph_representations',
                                  dataset_kwargs=dataset_kwargs,
                                  out_channels=out_channels)

# %%
graph_dataset_test[0]
# Out:
# Data(x=[12, 187], edge_index=[2, 142], y=[12, 48], edge_weight=[142], mask_X=[12, 187], mask_y=[12, 48], y_scaled=[12, 48])

# %% [markdown]
# ## Training a graph model

# %% [markdown]
# To train your graph models, the GraphToolbox has a training module. To use it, you need to instantiate a `Trainer` object which takes four arguments: `model` which is a graph model, and three GraphDataset objects `dataset_train`, `dataset_val` and `dataset_test`. There are other keyword arguments that you can find in the documentation. Then, when your trainer is instantiated, you can use the `train()` method. Note that if there is a pre-trained model with the same parameters, the trainer will automatically load the pre-trained weights (if you want to train another model with the same parameters, you will need to enforce `force_training=True` in the `train()` method).

# %%
gc.collect()
torch.cuda.empty_cache()
seed_everything(seed=42)

# conv_class = GATv2Conv
# conv_kwargs = {'heads': 2}
# params = {'num_layers': 2, 'hidden_channels': 359, 'lr': 4e-4, 'batch_size': 32, 'adj_matrix': 'space', 'lam_reg': 0}

# conv_class = GATConv
# conv_kwargs = {'heads': 2}
# params = {'num_layers': 3, 'hidden_channels': 364, 'lr': 1e-3, 'batch_size': 16, 'adj_matrix': 'gl3sr', 'lam_reg': 0}

# conv_class = ChebConv
# conv_kwargs = {'K': 3}
# params = {'num_layers': 1, 'hidden_channels': 249, 'lr': 6e-4, 'batch_size': 16, 'adj_matrix': 'distsplines', 'lam_reg': 0}

# conv_class = APPNP
# conv_kwargs = {'K': 1, 'alpha': .94}
# params = {'num_layers': 1, 'hidden_channels': 106, 'lr': 2e-3, 'batch_size': 16, 'adj_matrix': 'space'}

conv_class = LEConv
conv_kwargs = {}
params = {'num_layers': 2, 'hidden_channels': 256, 'lr': 1e-3, 'batch_size': 16, 'adj_matrix': 'space', 'lam_reg': 0}


graph_dataset_train._set_adj_matrix(adj_matrix=params['adj_matrix'])
graph_dataset_val._set_adj_matrix(adj_matrix=params['adj_matrix'])
graph_dataset_test._set_adj_matrix(adj_matrix=params['adj_matrix'])

model = myGNN(
    in_channels=graph_dataset_train.num_node_features,
    num_layers=params["num_layers"],
    hidden_channels=params["hidden_channels"],
    out_channels=out_channels,
    conv_class=conv_class,
    conv_kwargs=conv_kwargs
)


trainer = Trainer(
    model=model,
    dataset_train=graph_dataset_train,
    dataset_val=graph_dataset_val,
    dataset_test=graph_dataset_test,
    batch_size=params["batch_size"],
    model_kwargs={'lr': params["lr"], 'num_epochs': 300},
    reconcile=True,
    top_level_model='xgb',
    lam_reg=0
)

pred_model_test, target_test, edge_index, attention_weights = trainer.train(
    plot_loss=True,
    force_training=False,
    save=True,
    patience=75
)
trainer.evaluate()
# Out:
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
# MAPE on test set: 1.1178 %
# RMSE on test set: 835.6810 MW

# %% [markdown]
# To visualize your predictions for each node, you can use the `plot_nodes()` method.

# %%
plot_nodes(true=target_test, pred=pred_model_test, graph_dataset=graph_dataset_test)

# %% [markdown]
# # Optimizing a model

# %% [markdown]
# GNNs are a category of models that have a lot of hyperparameters which need to be tuned. The optimization module of the GraphToolbox uses Optuna, which is a well known optimization framework especially in the field of deep-learning.

# %%
OPTIMIZE = True

optim_base = {
    'num_layers': (1, 5),
    'hidden_channels': (32, 512),
    'lr': (1e-5, 1e-1),
}

_with_heads = optim_base | {'heads': (1, 5)}
_with_K     = optim_base | {'K': (1, 10)}

optim_kwargs_conv = {
    # GCN / Spectral
    'GCNConv':           optim_base,
    'ChebConv':          _with_K,
    'SGConv':            _with_K,
    'SSGConv':           optim_base | {'alpha': (0.0, 1.0)},
    'LGConv':            optim_base,
    'GCN2Conv':          optim_base | {'alpha': (0.0, 1.0)},
    'ClusterGCNConv':    optim_base,
    'FAConv':            optim_base,
    # Attention-based
    'GATConv':           _with_heads,
    'GATv2Conv':         _with_heads,
    'SuperGATConv':      _with_heads,
    'TransformerConv':   _with_heads,
    'AGNNConv':          optim_base,
    'DNAConv':           optim_base | {'heads': (1, 5), 'K': (1, 10)},
    # MPNN / Aggregation
    'SAGEConv':          optim_base,
    'GENConv':           optim_base,
    'GraphConv':         optim_base,
    'MFConv':            optim_base,
    'LEConv':            optim_base,
    'SimpleConv':        optim_base,
    'EGConv':            optim_base,
    'GravNetConv':       optim_base,
    # MLP-based (GIN-style)
    'GINConv':           optim_base,
    'GINEConv':          optim_base,
    # Edge-conditioned
    'NNConv':            optim_base,
    'ECConv':            optim_base,
    'CGConv':            optim_base,
    'GMMConv':           optim_base,
    'GeneralConv':       _with_heads,
    'XConv':             optim_base,
    # Recurrent / Gated
    'GatedGraphConv':    optim_base,
    'ARMAConv':          optim_base,
    'TAGConv':           _with_K,
    # Residual / Deep
    'DirGNNConv':        optim_base | {'alpha': (0.0, 1.0)},
    'AntiSymmetricConv': optim_base | {'gamma': (0.01, 1.0), 'epsilon': (0.01, 1.0)},
    'FiLMConv':          optim_base,
    'ResGatedGraphConv': optim_base,
    'PDNConv':           optim_base,
    # Spectral / Poly
    'MixHopConv':        optim_base,
    'GPSConv':           optim_base,
    'FeaStConv':         optim_base,
    'PANConv':           optim_base,
    # Dynamic aggregators
    'PNAConv':           optim_base,
    'EdgeConv':          optim_base,
    'DynamicEdgeConv':   optim_base | {'k': (3, 15)},
    # Relational
    'RGCNConv':          optim_base,
    'RGATConv':          _with_heads,
    'FastRGCNConv':      optim_base,
    # Graph-level
    'WLConv':            optim_base,
    'SignedConv':        optim_base,
    # APPNP
    'APPNP':             _with_K | {'alpha': (0.5, 1.0)},
}

if OPTIMIZE:
    conv_class = APPNP
    optim_kwargs = optim_kwargs_conv[conv_class.__name__]
    optimizer = Optimizer(model=myGNN,
                        dataset_train=graph_dataset_train,
                        dataset_val=graph_dataset_val,
                        conv_class=conv_class,
                        num_epochs=100,
                        optim_kwargs=optim_kwargs)
    optimizer.optimize(n_trials=200)
# Out:
# [I 2026-07-08 18:15:25,849] A new study created in memory with name: myGNN_hpo
# 100%|██████████| 100/100 [00:16<00:00,  6.24it/s]
# [I 2026-07-08 18:15:41,920] Trial 0 finished with value: 0.21184824407100677 and parameters: {'num_layers': 3, 'hidden_channels': 479, 'lr': 1.269269029716524e-05, 'K': 4, 'alpha': 0.8738571919081801, 'batch_size': 128, 'adj_matrix': 'exp_dtw'}. Best is trial 0 with value: 0.21184824407100677.
# 100%|██████████| 100/100 [00:02<00:00, 39.11it/s]
# [I 2026-07-08 18:15:44,519] Trial 1 finished with value: 0.017508015036582947 and parameters: {'num_layers': 1, 'hidden_channels': 201, 'lr': 0.0001314357175274956, 'K': 10, 'alpha': 0.9062621866131122, 'batch_size': 64, 'adj_matrix': 'gl3sr'}. Best is trial 1 with value: 0.017508015036582947.
# 100%|██████████| 100/100 [00:04<00:00, 21.22it/s]
# ...

# %% [markdown]
# ## An additive graph model
#
# Before sweeping the convolutions, we fit an `AdditiveGraphModel`, a GAM-like graph network that encodes disjoint feature groups with separate encoders and sums their contributions over a shared backbone. It is an interpretable, additive alternative to a monolithic convolution and trains through the same `Trainer`. Its only requirement is a partition of the features into contiguous groups, which we derive from the resolved feature list: the exogenous base block, the load-lag block, the temperature-lag block, and the trailing calendar dummies.

# %%
from graphtoolbox.models import AdditiveGraphModel
import re

# AdditiveGraphModel slices the node-feature vector by consecutive offsets, so the
# groups must be CONTIGUOUS blocks of the physical feature order and together cover
# every column. We build four such blocks from the resolved feature list.
def _agm_kind(f):
    if re.fullmatch(r'load_l\d+', f):   return 'load_lags'
    if re.fullmatch(r'temp_l-?\d+', f): return 'temp_lags'
    return 'exogenous'

_feats = list(graph_dataset_train.features)
_runs = []
for f in _feats:
    k = _agm_kind(f)
    if _runs and _runs[-1][0] == k:
        _runs[-1][1].append(f)
    else:
        _runs.append([k, [f]])
_n_exo = sum(1 for k, _ in _runs if k == 'exogenous')
AGM_GROUPS, _exo = {}, 0
for k, fs in _runs:
    if k == 'exogenous':
        _exo += 1
        name = 'exogenous' if _n_exo == 1 else ('exogenous' if _exo == 1 else 'calendar_dummies')
    else:
        name = k
    AGM_GROUPS[name] = AGM_GROUPS.get(name, 0) + len(fs)
assert sum(AGM_GROUPS.values()) == graph_dataset_train.num_node_features, "groups must tile all features"
print('Feature groups (contiguous):', AGM_GROUPS, '| total =', graph_dataset_train.num_node_features)

# Same defaults as the convolution sweep, trained through the same harness.
AGM_ADJ = 'dtw'
for _ds in (graph_dataset_train, graph_dataset_val, graph_dataset_test):
    _ds._set_adj_matrix(adj_matrix=AGM_ADJ)
seed_everything(42)
gc.collect()

model_additive = AdditiveGraphModel(
    feature_group_dims=AGM_GROUPS,
    num_layers=2, hidden_channels=64, out_channels=out_channels,
    conv_class=GCNConv, conv_kwargs={},
)
trainer_additive = Trainer(
    model=model_additive,
    dataset_train=graph_dataset_train, dataset_val=graph_dataset_val, dataset_test=graph_dataset_test,
    batch_size=32, model_kwargs={'lr': 1e-3, 'num_epochs': 300},
    reconcile=True, top_level_model='xgb', lam_reg=0,
)
_res = trainer_additive.train(force_training=False, patience=30)
pred_additive, target_additive = _res[0], _res[1]
# AdditiveGraphModel auto-returns per-group contributions (Trainer contract).
group_outputs_additive = _res[4] if len(_res) >= 5 else None

_mape = 100 * MAPE(pred_additive.sum(dim=0).cpu().detach(), target_additive.sum(dim=0).cpu()).item()
_rmse = RMSE(pred_additive.sum(dim=0).cpu().detach(), target_additive.sum(dim=0).cpu()).item()
print(f'\nAdditiveGraphModel  national MAPE = {_mape:.2f}%   RMSE = {_rmse:.0f} MW')
# To fold it into the aggregation / significance cells, add it after the sweep:
#   trained_preds['AdditiveGraphModel'] = pred_additive
# Out:
# Feature groups (contiguous): {'exogenous': 14, 'load_lags': 48, 'temp_lags': 47, 'calendar_dummies': 78} | total = 187
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#
# AdditiveGraphModel  national MAPE = 1.22%   RMSE = 902 MW

# %% [markdown]
# The additive structure makes the model directly interpretable: each feature group contributes an additive term to the forecast, so we can read how much each group drives the prediction and with what temporal pattern.

# %%
import matplotlib.pyplot as plt
import numpy as np

assert group_outputs_additive is not None, 'Run the AdditiveGraphModel training cell first.'

# The additive model combines groups by AVERAGE, not sum (y_hat = bias + mean_g Y_g),
# and the Trainer unscales each group independently (adding the load-level mean to every
# group) and reconciles the final forecast with MinT. The raw group outputs therefore do
# NOT sum to the load: their sum is about G times the load level. To recover a faithful
# additive decomposition we average the groups (divide by G) and de-mean them; the result
# sums EXACTLY to the raw (pre-reconciliation) forecast dynamics.
_G = len(group_outputs_additive)
_contrib = {g: c.sum(dim=0).cpu().detach().numpy() / _G for g, c in group_outputs_additive.items()}
_dev = {g: v - v.mean() for g, v in _contrib.items()}          # per-group contribution to dynamics
_raw_dyn = sum(_dev.values())                                   # = raw forecast dynamics (exact)
_fc = pred_additive.sum(dim=0).cpu().detach().numpy()           # MinT-reconciled forecast
_fc_dyn = _fc - _fc.mean()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Panel 1: additive decomposition of the forecast dynamics over the first two weeks.
# The individual group contributions sum to the raw forecast (black); the reconciled
# forecast (red dashed) differs only by the MinT adjustment.
_win = slice(0, min(48 * 14, _raw_dyn.size))
_x = np.arange(_win.stop)
for g, v in _dev.items():
    ax1.plot(_x, v[_win], linewidth=1.2, label=g)
ax1.plot(_x, _raw_dyn[_win], color='black', linewidth=1.6, label='sum of groups (= raw forecast)')
ax1.plot(_x, _fc_dyn[_win], color='crimson', linewidth=1.0, linestyle='--', label='reconciled forecast')
ax1.set_xlabel('Half-hour (first two weeks of the test set)')
ax1.set_ylabel('De-meaned contribution (MW)')
ax1.set_title('Additive decomposition of the forecast dynamics')
ax1.legend(fontsize=8, ncol=2)

# Panel 2: importance = temporal variability each group injects (std of its contribution).
_imp = {g: float(np.std(v)) for g, v in _contrib.items()}
_order = sorted(_imp, key=_imp.get, reverse=True)
_bars = ax2.barh(_order, [_imp[g] for g in _order], color='#4c72b0', edgecolor='white')
ax2.bar_label(_bars, fmt='%.0f MW', padding=3, fontsize=8)
ax2.invert_yaxis()
ax2.set_xlabel('Std of contribution (MW)')
ax2.set_title('Feature-group importance (variability explained)')

plt.tight_layout(); plt.show()

_gap = float(np.sqrt(np.mean((_raw_dyn - _fc_dyn) ** 2)))
print('The averaged, de-meaned group contributions sum exactly to the raw forecast dynamics.')
print(f'Gap between raw sum and the MinT-reconciled forecast: RMSE = {_gap:.0f} MW (reconciliation).')
# Out:
# The averaged, de-meaned group contributions sum exactly to the raw forecast dynamics.
# Gap between raw sum and the MinT-reconciled forecast: RMSE = 334 MW (reconciliation).

# %% [markdown]
# ### Per-feature importance via accumulated local effects
#
# The group decomposition above is coarse. Accumulated local effects (ALE) refine it to a per-feature importance, measuring how much each individual feature moves its group's contribution across the range of its values. This is the interpretability tool the framework provides for additive models, and it reuses the group contributions already computed, so no retraining is needed.

# %%
import matplotlib.pyplot as plt
import re
from graphtoolbox.interpretability import (compute_feature_importances_from_ALE,
                                           plot_feature_importance_bar)

# The additive groups, this time as name lists for per-feature ALE. Feature values
# are read from data.df_test by get_group_feature_mats, so the dummy group is given
# its base names (which are expanded to their one-hot columns automatically).
def _agm_kind(f):
    if re.fullmatch(r'load_l\d+', f):   return 'load_lags'
    if re.fullmatch(r'temp_l-?\d+', f): return 'temp_lags'
    return 'exogenous'

_runs = []
for f in graph_dataset_train.features:
    k = _agm_kind(f)
    if _runs and _runs[-1][0] == k:
        _runs[-1][1].append(f)
    else:
        _runs.append([k, [f]])
_n_exo = sum(1 for k, _ in _runs if k == 'exogenous')
_feature_groups, _e = {}, 0
for k, fs in _runs:
    if k == 'exogenous':
        _e += 1
        nm = 'exogenous' if _n_exo == 1 else ('exogenous' if _e == 1 else 'calendar_dummies')
        _feature_groups[nm] = data_kwargs['dummies'] if nm == 'calendar_dummies' else fs
    else:
        _feature_groups[k] = fs
graph_dataset_train.dataset_kwargs['feature_groups'] = _feature_groups

# Scalar ALE importance of every feature within its group (averaged over the day).
importance_ale = compute_feature_importances_from_ALE(
    group_outputs_additive, data, graph_dataset_train, graph_dataset_test,
    n_bins=20, mode='avg48', period=48, method='rms',
)

# Top individual features.
plot_feature_importance_bar(importance_ale, top_k=20, normalize='sum')
plt.title('AdditiveGraphModel: top-20 feature importances (ALE)')
plt.tight_layout(); plt.show()

# Importance aggregated per feature group.
_grp = importance_ale.groupby('group')['importance'].sum().sort_values()
_share = 100 * _grp / _grp.sum()
fig, ax = plt.subplots(figsize=(8, 3.5))
_bars = ax.barh(_share.index, _share.values, color='#dd8452', edgecolor='white')
ax.bar_label(_bars, fmt='%.0f%%', padding=3, fontsize=8)
ax.set_xlabel('Share of total ALE importance (%)')
ax.set_title('AdditiveGraphModel: importance by feature group')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Training all working convolutions
#
# This section trains a `myGNN` with shared default hyperparameters for every compatible PyG convolution. Predictions are cached on disk so you can resume without retraining.

# %%
import gc
import inspect
import os
import re
from torch_geometric.nn import conv as pyg_conv

_skip_keywords = ['CuGraph', 'GPSConv', 'Hetero', 'HAN', 'HGT', 'HEAT', 'Point', 'PPF', 'Hypergraph', 'Spline', 'XConv', 'WLConv', 'DNAConv']

ALL_CONV_CLASSES = {}
_x_probe = torch.randn(15, graph_dataset_train.num_node_features)
_ei_probe = torch.randint(0, 15, (2, 40))

for _name, _cls in inspect.getmembers(pyg_conv, inspect.isclass):
    # if not _name.endswith('Conv'):
    #     continue
    if any(k in _name for k in _skip_keywords):
        continue
    try:
        _m = myGNN(
            in_channels=graph_dataset_train.num_node_features,
            hidden_channels=32,
            out_channels=out_channels,
            num_layers=2,
            conv_class=_cls,
        )
        with torch.no_grad():
            _out = _m(_x_probe, _ei_probe)
        if not torch.is_tensor(_out):
            raise ValueError
        del _m
        ALL_CONV_CLASSES[_name] = _cls
    except (ImportError, ModuleNotFoundError):
        pass
    except Exception:
        pass

del _x_probe, _ei_probe
print(f"Working convolutions ({len(ALL_CONV_CLASSES)}):")
for _n in ALL_CONV_CLASSES:
    print(f"  {_n}")
# Out:
# Working convolutions (47):
#   AGNNConv
#   APPNP
#   ARMAConv
#   AntiSymmetricConv
#   CGConv
#   ChebConv
#   ClusterGCNConv
#   DirGNNConv
#   DynamicEdgeConv
#   ECConv
#   EGConv
#   EdgeConv
#   FAConv
#   FastRGCNConv
#   FeaStConv
#   FiLMConv
#   GATConv
#   GATv2Conv
#   GCN2Conv
#   GCNConv
#   GENConv
#   GINConv
#   GINEConv
#   GMMConv
#   GatedGraphConv
#   GeneralConv
#   GraphConv
#   GravNetConv
#   LEConv
#   LGConv
#   MFConv
#   MixHopConv
#   NNConv
#   PANConv
#   PDNConv
#   PNAConv
#   RGATConv
#   RGCNConv
#   ResGatedGraphConv
#   SAGEConv
#   SGConv
#   SSGConv
#   SignedConv
#   SimpleConv
#   SuperGATConv
#   TAGConv
#   TransformerConv

# %%
import json as _json
import hashlib as _hashlib
from inspect import signature as _sig, Parameter as _Param

# Params that belong to myGNN.__init__ directly (excluding fixed inputs and **kwargs)
_GNN_CTOR_PARAMS = {
    p.name for p in _sig(myGNN.__init__).parameters.values()
    if p.name not in ('self', 'in_channels', 'out_channels', 'conv_class', 'conv_kwargs')
    and p.kind not in (_Param.VAR_KEYWORD, _Param.VAR_POSITIONAL)
}
# Params consumed at the sweep level, not forwarded to the model constructor
_SWEEP_LEVEL = {'num_layers', 'hidden_channels', 'lr', 'batch_size', 'adj_matrix', 'heads'}

def _resolve_params(conv_name):
    """Return (run_params, model_kw, conv_kw, source) for a convolution.

    Loads ./results_optim_{conv_name}/myGNN_best.json when available and
    falls back to LOOP_PARAMS otherwise.

    run_params  -- num_layers, hidden_channels, lr, batch_size, adj_matrix, heads,
                   num_epochs, patience (last two always taken from LOOP_PARAMS)
    model_kw    -- extra myGNN constructor params found in best (beyond those above)
    conv_kw     -- conv-specific params found in best (e.g. K, alpha, k)
    source      -- 'optimized' or 'default'
    """
    json_path = f'./results_optim_{conv_name}/myGNN_best.json'
    if os.path.exists(json_path):
        with open(json_path) as _f:
            best = _json.load(_f)['params']
        source = 'optimized'
    else:
        best = {}
        source = 'default'

    run_params = {
        'num_layers':    int(best.get('num_layers',    LOOP_PARAMS['num_layers'])),
        'hidden_channels': int(best.get('hidden_channels', LOOP_PARAMS['hidden_channels'])),
        'lr':            float(best.get('lr',            LOOP_PARAMS['lr'])),
        'batch_size':    int(best.get('batch_size',    LOOP_PARAMS['batch_size'])),
        'adj_matrix':    best.get('adj_matrix',    LOOP_PARAMS['adj_matrix']),
        'heads':         int(best.get('heads',         LOOP_PARAMS['heads'])),
        'num_epochs':    LOOP_PARAMS['num_epochs'],
        'patience':      LOOP_PARAMS['patience'],
    }
    # Extra model-constructor params not already covered by run_params (e.g. heads)
    model_kw = {k: v for k, v in best.items()
                if k in _GNN_CTOR_PARAMS and k not in _SWEEP_LEVEL}
    # Conv-specific params (e.g. K, alpha, k, gamma, epsilon)
    conv_kw  = {k: v for k, v in best.items()
                if k not in _GNN_CTOR_PARAMS and k not in _SWEEP_LEVEL}

    return run_params, model_kw, conv_kw, source


# Default hyperparameters for the sweep (used when no optimized params exist)
# LOOP_PARAMS = {
#     'num_layers':     2,
#     'hidden_channels': 256,
#     'lr':             1e-3,
#     'batch_size':     16,
#     'adj_matrix':     'space',
#     'heads':          1,
#     'num_epochs':     300,
#     'patience':       30,
#     'reconcile':      True,
# }
LOOP_PARAMS = {
    'num_layers':     2,
    'hidden_channels': 64,
    'lr':             1e-3,
    'batch_size':     32,
    'adj_matrix':     'dtw',
    'heads':          4,       # attention convs use this many heads (ignored by non-attention convs)
    'num_epochs':     300,
    'patience':       30,
    'reconcile':      True,
}
RESULTS_DIR = './results_all_convolutions'
os.makedirs(RESULTS_DIR, exist_ok=True)

# Track whether LOOP_PARAMS changed since the last run.
# Legacy caches (no sidecar) are treated as stale when defaults changed.
_loop_state_path = os.path.join(RESULTS_DIR, '_loop_params.json')
_last_loop_params = None
if os.path.exists(_loop_state_path):
    with open(_loop_state_path) as _lf:
        _last_loop_params = _json.load(_lf)
_loop_params_unchanged = (_last_loop_params is None or _last_loop_params == LOOP_PARAMS)
with open(_loop_state_path, 'w') as _lf:
    _json.dump(LOOP_PARAMS, _lf)

trained_preds  = {}      # conv_name -> [num_nodes, T] tensor
target_national = None   # [T] float tensor, same for every model
target_nodes   = None   # [num_nodes, T] tensor, for per-node aggregation
failed_loop    = {}

_target_path       = os.path.join(RESULTS_DIR, 'target.pt')
_target_nodes_path = os.path.join(RESULTS_DIR, 'target_nodes.pt')
_current_adj  = LOOP_PARAMS['adj_matrix']

# Set initial adjacency matrix
for _ds in [graph_dataset_train, graph_dataset_val, graph_dataset_test]:
    _ds._set_adj_matrix(adj_matrix=_current_adj)

for conv_name, cls in ALL_CONV_CLASSES.items():
    # --- resolve config, then cache predictions per configuration ---
    _params, _model_kw, _conv_kw, _src = _resolve_params(conv_name)
    _current_params_key = {**_params, **_model_kw, **_conv_kw,
                        'reconcile': LOOP_PARAMS['reconcile']}
    # heads only changes attention convs; drop it from the cache key of the
    # others so changing LOOP_PARAMS['heads'] does not needlessly retrain them.
    if 'heads' not in _sig(cls).parameters:
        _current_params_key.pop('heads', None)
    # Each (conv, config) pair gets its own cache file, so switching between
    # configurations (e.g. heads=2 <-> heads=4) keeps every trained result and
    # never retrains a configuration already computed.
    _cfg = _hashlib.md5(_json.dumps(_current_params_key, sort_keys=True).encode()).hexdigest()[:10]
    pred_path    = os.path.join(RESULTS_DIR, f'{conv_name}__{_cfg}.pt')
    _params_path = os.path.join(RESULTS_DIR, f'{conv_name}__{_cfg}.json')

    # One-time migration: adopt a legacy single-config cache ({conv}.pt) when its
    # stored key matches this configuration, so existing valid caches are kept.
    _legacy_pred = os.path.join(RESULTS_DIR, f'{conv_name}.pt')
    _legacy_side = os.path.join(RESULTS_DIR, f'{conv_name}_params.json')
    if (not os.path.exists(pred_path)) and os.path.exists(_legacy_pred) and os.path.exists(_legacy_side):
        with open(_legacy_side) as _lf:
            if _json.load(_lf) == _current_params_key:
                os.replace(_legacy_pred, pred_path)
                os.replace(_legacy_side, _params_path)

    # --- cache hit: this configuration is already on disk ---
    if os.path.exists(pred_path) and os.path.exists(_params_path):
        with open(_params_path) as _pf:
            _stored = _json.load(_pf)
        if _stored == _current_params_key:          # guard against hash collision
            trained_preds[conv_name] = torch.load(pred_path, weights_only=False)
            if target_national is None and os.path.exists(_target_path):
                target_national = torch.load(_target_path, weights_only=False)
            if target_nodes is None and os.path.exists(_target_nodes_path):
                target_nodes = torch.load(_target_nodes_path, weights_only=False)
            print(f'⏩ {conv_name:<25} loaded from cache  [{_src}] cfg={_cfg}')
            continue

    print(f'\nTraining {conv_name}... [{_src}]')
    if _src == 'optimized':
        _detail = (f'   layers={_params["num_layers"]}  hidden={_params["hidden_channels"]}'
                   f'  lr={_params["lr"]:.2e}  batch={_params["batch_size"]}'
                   f'  adj={_params["adj_matrix"]}  heads={_params["heads"]}')
        if _model_kw: _detail += f'  model_kw={_model_kw}'
        if _conv_kw:  _detail += f'  conv_kw={_conv_kw}'
        print(_detail)
    seed_everything(42)
    gc.collect()

    # Switch adjacency matrix when the optimized params require a different one
    if _params['adj_matrix'] != _current_adj:
        for _ds in [graph_dataset_train, graph_dataset_val, graph_dataset_test]:
            _ds._set_adj_matrix(adj_matrix=_params['adj_matrix'])
        _current_adj = _params['adj_matrix']

    try:
        _model = myGNN(
            in_channels=graph_dataset_train.num_node_features,
            num_layers=_params['num_layers'],
            hidden_channels=_params['hidden_channels'],
            out_channels=out_channels,
            conv_class=cls,
            conv_kwargs=_conv_kw or None,
            heads=_params['heads'],
            **_model_kw,
        )

        _trainer = Trainer(
            model=_model,
            dataset_train=graph_dataset_train,
            dataset_val=graph_dataset_val,
            dataset_test=graph_dataset_test,
            batch_size=_params['batch_size'],
            model_kwargs={'lr': _params['lr'], 'num_epochs': _params['num_epochs']},
            reconcile=LOOP_PARAMS['reconcile'],
            top_level_model='xgb',
            lam_reg=0,
        )

        _result = _trainer.train(force_training=False, patience=_params['patience'])
        _pred, _target = _result[0], _result[1]

        torch.save(_pred, pred_path)
        with open(_params_path, 'w') as _pf:
            _json.dump(_current_params_key, _pf)
        trained_preds[conv_name] = _pred

        if target_national is None:
            target_national = _target.sum(dim=0).cpu()
            torch.save(target_national, _target_path)
            target_nodes = _target.cpu()
            torch.save(target_nodes, _target_nodes_path)

        _mape = 100 * MAPE(
            preds=_pred.sum(dim=0).cpu().detach(),
            targets=_target.sum(dim=0).cpu()
        ).item()
        print(f'  MAPE national = {_mape:.2f}%')

    except Exception as e:
        _msg = str(e).splitlines()[0] if str(e).strip() else type(e).__name__
        failed_loop[conv_name] = _msg
        print(f'  Failed: {_msg}')

    gc.collect()

print(f'\nSuccessfully trained / cached: {len(trained_preds)}')
if failed_loop:
    print(f'Failed during real-data training: {list(failed_loop.keys())}')
# Out:
# ⏩ AGNNConv                  loaded from cache  [default] cfg=37f94532b2
# ⏩ APPNP                     loaded from cache  [optimized] cfg=9cc5b4738f
# ⏩ ARMAConv                  loaded from cache  [default] cfg=37f94532b2
# ⏩ AntiSymmetricConv         loaded from cache  [default] cfg=37f94532b2
# ⏩ CGConv                    loaded from cache  [default] cfg=37f94532b2
# ⏩ ChebConv                  loaded from cache  [default] cfg=37f94532b2
# ⏩ ClusterGCNConv            loaded from cache  [default] cfg=37f94532b2
# ⏩ DirGNNConv                loaded from cache  [default] cfg=37f94532b2
# ⏩ DynamicEdgeConv           loaded from cache  [default] cfg=37f94532b2
# ⏩ ECConv                    loaded from cache  [default] cfg=37f94532b2
# ⏩ EGConv                    loaded from cache  [default] cfg=37f94532b2
# ⏩ EdgeConv                  loaded from cache  [default] cfg=37f94532b2
# ⏩ FAConv                    loaded from cache  [default] cfg=37f94532b2
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Compute MAPE and RMSE per convolution and flag which already have optimized params
_scores = {}
_rmse = {}
for _name, _pred in trained_preds.items():
    _pred_nat = _pred.sum(dim=0).cpu().detach()
    _scores[_name] = 100 * MAPE(preds=_pred_nat, targets=target_national.cpu()).item()
    _rmse[_name]   = RMSE(preds=_pred_nat, targets=target_national.cpu()).item()

_names   = sorted(_scores, key=_scores.get)          # best (lowest MAPE) first
_values  = [_scores[n] for n in _names]
_rvalues = [_rmse[n]   for n in _names]
_has_hpo = [os.path.exists(f'./results_optim_{n}/myGNN_best.json') for n in _names]

_colors = ['#2ecc71' if h else '#3498db' for h in _has_hpo]

fig, (ax_mape, ax_rmse) = plt.subplots(
    1, 2, sharey=True, figsize=(14, max(4, 0.35 * len(_names)))
)

bars_mape = ax_mape.barh(_names, _values, color=_colors, edgecolor='white', linewidth=0.4)
ax_mape.bar_label(bars_mape, fmt='%.2f%%', padding=3, fontsize=8)
ax_mape.set_xlabel('MAPE national (%)')
ax_mape.set_title('National MAPE (lower is better)')
ax_mape.invert_yaxis()

bars_rmse = ax_rmse.barh(_names, _rvalues, color=_colors, edgecolor='white', linewidth=0.4)
ax_rmse.bar_label(bars_rmse, fmt='%.0f', padding=3, fontsize=8)
ax_rmse.set_xlabel('RMSE national (MW)')
ax_rmse.set_title('National RMSE (lower is better)')

fig.suptitle('Convolution benchmark - national errors (sorted by MAPE)')

from matplotlib.patches import Patch
ax_rmse.legend(handles=[
    Patch(color='#2ecc71', label='HPO done'),
    Patch(color='#3498db', label='Default params'),
], loc='lower right', fontsize=8)

plt.tight_layout()
plt.show()

# Print ranking for easy copy-paste into the HPO cell
print(f'\n{"Rank":<5} {"Convolution":<25} {"MAPE":>8} {"RMSE":>10}  HPO')
print('-' * 58)
for _rank, _name in enumerate(_names, 1):
    _marker = '*' if _has_hpo[_rank - 1] else ' '
    print(f'{_rank:<5} {_name:<25} {_scores[_name]:>7.2f}% {_rmse[_name]:>8.0f} MW  {_marker}')
# Out:
# Rank  Convolution                   MAPE       RMSE  HPO
# ----------------------------------------------------------
# 1     LEConv                       1.12%      836 MW  *
# 2     GatedGraphConv               1.16%      848 MW
# 3     GCNConv                      1.16%      908 MW
# 4     ResGatedGraphConv            1.16%      872 MW
# 5     GATv2Conv                    1.17%      869 MW
# 6     RGATConv                     1.17%      884 MW
# 7     RGCNConv                     1.18%      900 MW
# 8     GATConv                      1.19%      902 MW  *
# 9     FastRGCNConv                 1.19%      915 MW
# 10    TransformerConv              1.20%      913 MW
# 11    SGConv                       1.20%      884 MW
# 12    PDNConv                      1.21%      928 MW
# 13    ARMAConv                     1.21%      884 MW
# 14    SuperGATConv                 1.21%      908 MW
# 15    MixHopConv                   1.21%      907 MW
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

N = len(_names)

theta = np.linspace(0, 2*np.pi, N, endpoint=False)
radius = np.array(_values)

sizes = 30 + 120 * (
    (np.array(_rvalues) - np.min(_rvalues))
    / (np.max(_rvalues) - np.min(_rvalues) + 1e-8)
)

colors = np.where(_has_hpo, "#2ecc71", "#3498db")

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111, projection="polar")

ax.scatter(theta, radius,
           s=sizes,
           c=colors)

ax.set_xticks([])
ax.set_yticklabels([])

for t, r, name in zip(theta, radius, _names):
    ax.text(t, radius.max()+0.4,
            name,
            rotation=np.degrees(t),
            rotation_mode='anchor',
            ha='center',
            va='center',
            fontsize=8)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 7))

rank = np.arange(len(_values))

sc = ax.scatter(
    _values,
    _rvalues,
    c=rank,
    cmap="viridis_r",      # meilleur = jaune
    s=90,
    edgecolors="white",
    linewidths=0.8,
    zorder=3,
)

# Annoter uniquement les meilleurs et les pires
to_label = list(range(10)) + list(range(len(_names)-5, len(_names)))

for i in to_label:
    ax.annotate(
        _names[i],
        (_values[i], _rvalues[i]),
        xytext=(5, 5),
        textcoords="offset points",
        fontsize=9,
    )

ax.set_xlabel("MAPE (%)")
ax.set_ylabel("RMSE (MW)")
ax.set_title("Benchmark of graph convolutions")

ax.grid(alpha=0.25)

# Barre de couleur = rang
cbar = plt.colorbar(sc, ax=ax)
cbar.set_label("Rank (MAPE)")
cbar.set_ticks([0, len(rank)-1])
cbar.set_ticklabels(["Best", "Worst"])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Significance testing
#
# The comparison above ranks convolutions by point error, but a ranking alone does not say whether the differences are statistically meaningful. Since the reconciled forecasts are already cached in `trained_preds`, significance is assessed directly on the error series, without retraining a single model.
#
# `graphtoolbox.evaluation` provides three tools. A moving-block bootstrap attaches a standard error and a confidence interval to each RMSE while respecting the temporal dependence of the errors. The Diebold-Mariano test compares the predictive accuracy of two forecasts, here against the best model and with a Holm correction for the many pairwise comparisons. The Model Confidence Set returns the convolutions that are statistically indistinguishable from the best at a chosen level.

# %%
from graphtoolbox.evaluation import bootstrap_table, pairwise_dm, model_confidence_set

# National forecasts read straight from the cache; no model is instantiated here.
_national = {name: pred.sum(dim=0) for name, pred in trained_preds.items()}
_y = target_national

# 1) Standard errors and 95% CIs on the national RMSE, via a moving-block
#    bootstrap (block = 48 half-hours = one day) that respects error dependence.
_se = bootstrap_table(_national, _y, metric='rmse', n_boot=2000, block_len=48, seed=0)
print('National error with bootstrap standard errors (MW):')
print(_se.round(3).to_string())

# 2) Diebold-Mariano tests against the best model, Holm-corrected across pairs.
_best = _se.index[0]
_dm = pairwise_dm(_national, _y, loss='squared', h=48, correction='holm')
_col = _dm['pvalue_adjusted'][_best].drop(_best).sort_values()
print(f'\nDiebold-Mariano vs best ({_best}), Holm-adjusted p-values '
      f'(ns: p>0.05, *: p>0.01, **: p<=0.01):')
for _name, _p in _col.items():
    _mark = 'ns' if _p > 0.05 else ('*' if _p > 0.01 else '**')
    print(f'  {_name:<20} p={_p:.4f}  {_mark}')

# 3) Model Confidence Set: convolutions indistinguishable from the best.
_mcs = model_confidence_set(_national, _y, loss='squared', alpha=0.10,
                            n_boot=2000, block_len=48, seed=0)
print(f'\nModel Confidence Set (alpha=0.10): {len(_mcs.included)} model(s)')
print('  ' + ', '.join(_mcs.included))
# Out:
# National error with bootstrap standard errors (MW):
#                        rmse      se    ci_low   ci_high
# LEConv              835.681  35.620   764.068   902.885
# GatedGraphConv      848.474  33.798   780.364   912.049
# GATv2Conv           868.809  33.153   801.845   931.245
# ResGatedGraphConv   872.303  41.005   793.445   950.893
# ARMAConv            883.713  32.697   810.986   942.812
# SGConv              884.135  35.286   808.119   944.176
# RGATConv            884.245  36.841   811.477   955.404
# SAGEConv            895.660  35.147   818.499   959.060
# RGCNConv            900.487  46.481   805.628   978.666
# GATConv             901.542  43.715   814.252   980.409
# MixHopConv          907.295  41.699   824.602   985.658
# SuperGATConv        907.683  41.673   828.072   991.850
# GCNConv             907.742  51.077   806.113  1002.085
# PANConv             908.876  37.262   835.283   979.776
# TransformerConv     912.826  37.751   835.198   979.771
# ...

# %% [markdown]
# ## Temporal convolutions
#
# The convolution sweep above feeds each model the full node-feature vector, in which the 48 load lags `load_l1` ... `load_l48` sit next to the calendar, weather and dummy features with no particular ordering. A static graph convolution performs a single spatio-temporal update and treats a lag exactly like any other feature.
#
# Temporal graph cells (`GConvGRU`, `DCRNN`, `TGCN`, `A3TGCN` from PyG-Temporal) are designed to exploit the sequential nature of those lags. `TemporalGNN` and its `ConvAdapterTemporal` reconstruct the `load_l*` columns as an ordered 48-step sequence, unroll the recurrent cell along it while carrying a graph-aware hidden state, then concatenate the remaining columns as static context before the forecast head. The lag / non-lag split is read from the `{target}_l{k}` naming produced by `features_to_lag`, so passing `target='load'` (the default) is how you declare which features are the sequence and which are static.

# %%
import os
import gc
import torch
from graphtoolbox.models import TemporalGNN
from graphtoolbox.training import set_device

# On small graphs (12 nodes here) CPU beats MPS by ~5x for recurrent cells:
# kernel-launch overhead dominates the tiny per-step workloads. Measured on an
# M4 Pro: 824 ms/batch on MPS vs 171 ms on CPU, and 83 ms with the fast
# GConvGRU unroll that ConvAdapterTemporal enables automatically.
set_device('cpu')

# Temporal graph cells from PyG-Temporal. Unlike the static sweep above, which
# consumed the 48 load lags as an unordered feature vector, TemporalGNN reads
# the `load_l*` columns as a genuine 48-step sequence (see ConvAdapterTemporal)
# and keeps every other column as static context.
try:
    from torch_geometric_temporal.nn.recurrent import GConvGRU, DCRNN, TGCN, A3TGCN
    TEMPORAL_CELLS = {
        # 'GConvGRU': (GConvGRU, {'K': 2}),
        # 'DCRNN':    (DCRNN,    {'K': 2}),
        # 'TGCN':     (TGCN,     {}),
        'A3TGCN':   (A3TGCN,   {}),          # periods auto-set to the lag length
    }
except Exception as _exc:
    TEMPORAL_CELLS = {}
    print('torch_geometric_temporal not installed; '
          'run `pip install torch-geometric-temporal` to enable temporal cells.')

TEMPORAL_HIDDEN = 128
TEMPORAL_DIR = './results_temporal'
os.makedirs(TEMPORAL_DIR, exist_ok=True)

# Temporal cells are trained on the same graph as the sweep.
for _ds in (graph_dataset_train, graph_dataset_val, graph_dataset_test):
    _ds._set_adj_matrix(adj_matrix=LOOP_PARAMS['adj_matrix'])

temporal_preds = {}
for _name, (_cell, _ckw) in TEMPORAL_CELLS.items():
    _pred_path = os.path.join(TEMPORAL_DIR, f'{_name}.pt')
    if os.path.exists(_pred_path):
        temporal_preds[_name] = torch.load(_pred_path, weights_only=False)
        print(f'⏩ {_name:<10} loaded from cache')
        continue

    print(f'\nTraining {_name} (temporal)...')
    seed_everything(42)
    gc.collect()

    # from_features derives the load-lag sequence and the static columns from the
    # `{target}_l{k}` naming; `target='load'` is the default.
    _model = TemporalGNN.from_features(
        graph_dataset_train.features,
        cell_class=_cell,
        hidden_channels=TEMPORAL_HIDDEN,
        out_channels=out_channels,
        cell_kwargs=_ckw or None,
    )
    _trainer = Trainer(
        model=_model,
        dataset_train=graph_dataset_train,
        dataset_val=graph_dataset_val,
        dataset_test=graph_dataset_test,
        batch_size=_params['batch_size'],
        model_kwargs={'lr': _params['lr'], 'num_epochs': 100},
        reconcile=True,
        top_level_model='xgb',
        lam_reg=0,
    )

    try:
        _result = _trainer.train(force_training=False, patience=LOOP_PARAMS['patience'])
        _pred = _result[0]
        torch.save(_pred, _pred_path)
        temporal_preds[_name] = _pred
        _nat = _pred.sum(dim=0).cpu().detach()
        _mape = 100 * MAPE(preds=_nat, targets=target_national.cpu()).item()
        _rmse = RMSE(preds=_nat, targets=target_national.cpu()).item()
        print(f'  MAPE = {_mape:.2f}%   RMSE = {_rmse:.0f} MW')
    except Exception as _exc:
        print(f'  Failed: {str(_exc).splitlines()[0]}')
    gc.collect()

# National summary, temporal cells sorted by MAPE.
if temporal_preds:
    print(f'\n{"Model":<12} {"MAPE":>8} {"RMSE":>10}')
    print('-' * 32)
    _ranked = sorted(
        temporal_preds.items(),
        key=lambda kv: MAPE(preds=kv[1].sum(dim=0).cpu().detach(),
                            targets=target_national.cpu()).item(),
    )
    for _name, _pred in _ranked:
        _nat = _pred.sum(dim=0).cpu().detach()
        _mape = 100 * MAPE(preds=_nat, targets=target_national.cpu()).item()
        _rmse = RMSE(preds=_nat, targets=target_national.cpu()).item()
        print(f'{_name:<12} {_mape:>7.2f}% {_rmse:>8.0f} MW')

# To let these temporal experts join the MLpol aggregation below, merge them in:
#   trained_preds.update(temporal_preds)
# Out:
# Training A3TGCN (temporal)...
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   MAPE = 2.39%   RMSE = 1683 MW
#
# Model            MAPE       RMSE
# --------------------------------
# A3TGCN          2.39%     1683 MW

# %% [markdown]
# ## Mixture of Experts (MLpol)
#
# The `graphtoolbox.aggregation` module implements online sequential aggregation. Here the MLpol algorithm combines the national-level forecasts of all trained convolution models in a data-adaptive way, updating the weights after each daily block.

# %%
import numpy as np
import pandas as pd

assert target_national is not None, "Run the training loop above first."
assert trained_preds, "No predictions available."

T = len(target_national)
step = out_channels                            # 48: one prediction block is one day
y = target_national.numpy().astype(float)      # national total ground truth [T]

# Experts matrix (T x K): national sum of each model's forecast, dropping any
# column that carries a non-finite value.
experts_df = pd.DataFrame(
    {name: preds.sum(dim=0).cpu().detach().numpy()[:T]
     for name, preds in trained_preds.items()}
)
bad_cols = experts_df.columns[~np.isfinite(experts_df.values).all(axis=0)].tolist()
if bad_cols:
    print(f"Dropping {len(bad_cols)} unstable expert(s): {bad_cols}")
    experts_df = experts_df.drop(columns=bad_cols)

print(f"Experts matrix: {experts_df.shape[1]} convolutions x {T} timesteps")
print(f"Block size: {step} (one day per update)\n")

# Baselines.
uniform_pred = experts_df.values.mean(axis=1)
print(f"Uniform average  -  RMSE: {RMSE(preds=uniform_pred, targets=y).item():>8.0f} MW   "
      f"MAPE: {100*MAPE(preds=uniform_pred, targets=y).item():.2f}%")
best_name = min(experts_df.columns,
                key=lambda n: MAPE(preds=experts_df[n].values.astype(float), targets=y).item())
print(f"Best individual  -  {best_name:<25}  "
      f"RMSE: {RMSE(preds=experts_df[best_name].values.astype(float), targets=y).item():>8.0f} MW   "
      f"MAPE: {100*MAPE(preds=experts_df[best_name].values.astype(float), targets=y).item():.2f}%")

# MLpol aggregation with the day-ahead block protocol: each 48-step day is
# forecast with the weights known at its start, then the weights advance within
# the day once it is observed.
agg = Aggregation(model="MLpol", loss="square").run(
    experts_df.values, y, block_size=step
)
predictions_agg = agg.prediction_
print(f"\nMLpol aggregation-  RMSE: {RMSE(preds=predictions_agg, targets=y).item():>8.0f} MW   "
      f"MAPE: {100*MAPE(preds=predictions_agg, targets=y).item():.2f}%")

# Final expert weights (those that would serve the next day).
final_weights = pd.Series(agg.coefficients_, index=experts_df.columns).sort_values(ascending=False)
print("\nFinal expert weights (top 10):")
for name, w in final_weights.head(10).items():
    print(f"  {name:<30} {w:.4f}")
# Out:
# Experts matrix: 48 convolutions x 17376 timesteps
# Block size: 48 (one day per update)
#
# Uniform average  -  RMSE:      846 MW   MAPE: 1.10%
# Best individual  -  LEConv                     RMSE:      836 MW   MAPE: 1.12%
#
# MLpol aggregation-  RMSE:      788 MW   MAPE: 1.02%
#
# Final expert weights (top 10):
#   GENConv                        0.4257
#   GATConv                        0.2307
#   GATv2Conv                      0.2026
#   LEConv                         0.1410
#   AGNNConv                       0.0000
#   PDNConv                        0.0000
#   GravNetConv                    0.0000
#   LGConv                         0.0000
#   MFConv                         0.0000
#   MixHopConv                     0.0000
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/graphtoolbox/aggregation/aggregation.py:390: RuntimeWarning: divide by zero encountered in matmul
#   preds[s:e] = X[s:e] @ p_block
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Reconstruct datetime index: 48 half-hours per day starting 2019-01-01
dates = pd.date_range(start='2019-01-01', periods=T, freq='30min')
months_idx = dates.to_period('M')
month_list = sorted(months_idx.unique())
month_short = [str(m)[-2:] for m in month_list]  # '01', '02', ...

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))

# --- Plot 1: Monthly MAPE ---
mlpol_mapes, uniform_mapes, best_mapes = [], [], []
for month in month_list:
    mask = (months_idx == month)
    y_m  = y[mask]
    mlpol_mapes.append(100 * float(MAPE(preds=predictions_agg[mask], targets=y_m)))
    uniform_mapes.append(100 * float(MAPE(preds=uniform_pred[mask], targets=y_m)))
    best_mapes.append(100 * float(MAPE(preds=experts_df[best_name].values[mask].astype(float), targets=y_m)))

x = np.arange(len(month_list))
w = 0.25
ax1.bar(x - w, mlpol_mapes,   w, label='MLpol',      color='steelblue')
ax1.bar(x,     uniform_mapes, w, label='Uniform avg',  color='silver')
ax1.bar(x + w, best_mapes,    w, label=best_name,      color='salmon')
ax1.set_xticks(x)
ax1.set_xticklabels(month_short)
ax1.set_xlabel('Month (2019)')
ax1.set_ylabel('MAPE (%)')
ax1.set_title('Monthly national MAPE')
ax1.legend()

# --- Plot 2: Top expert weights per month ---
N_top = 8
top_experts = final_weights.head(N_top).index.tolist()

# weights_mat is (T, K); take the weight vector at the last timestep of each month
weights_mat = np.asarray(agg.weights_)     # (T, K)
monthly_w = []
for month in month_list:
    last_t = int(np.where((months_idx == month))[0][-1])
    monthly_w.append(weights_mat[last_t])
monthly_w = np.array(monthly_w)           # (n_months, K)
weights_monthly_df = pd.DataFrame(monthly_w, columns=experts_df.columns, index=month_short)

for expert in top_experts:
    ax2.plot(month_short, weights_monthly_df[expert], marker='o', linewidth=1.8, label=expert)

ax2.set_xlabel('Month (2019)')
ax2.set_ylabel('Expert weight (MLpol)')
ax2.set_title(f'Top {N_top} expert weights over time')
ax2.legend(fontsize=8, bbox_to_anchor=(1.02, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Expert Pruning Analysis
#
# MLpol concentrates mass on very few experts over time. This cell analyses the full weight trajectory `agg.weights_` (shape T x K) to identify which convolutions ever carry non-negligible mass: the survivors that a `GatedMultiConv` needs to emulate.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Cumulative weight analysis
MEAN_THRESHOLD = 0.02   # above 2% mean weight = survivor
K_QUALITY      = 8      # top-K by mass coverage
K_DIVERSITY    = 5      # one per architecture family (max diversity)

weights_mat  = np.asarray(agg.weights_)     # (T, K)
mean_weights = weights_mat.mean(axis=0)
max_weights  = weights_mat.max(axis=0)

w_df = pd.DataFrame({
    'conv':        experts_df.columns,
    'mean_weight': mean_weights,
    'max_weight':  max_weights,
}).sort_values('mean_weight', ascending=False).reset_index(drop=True)

survivors = w_df[w_df['mean_weight'] > MEAN_THRESHOLD]['conv'].tolist()

# --- Architecture family labels ----------------------------------------------
_family = {
    'GatedGraphConv':    'recurrent',
    'ResGatedGraphConv': 'recurrent',
    'LEConv':            'edge-weighted',
    'GCNConv':           'spectral',
    'GENConv':           'aggregation',
    'SGConv':            'spectral',
    'SAGEConv':          'aggregation',
    'GraphConv':         'aggregation',
    'DNAConv':           'attention',
    'SuperGATConv':      'attention',
    'GCN2Conv':          'spectral',
    'SSGConv':           'spectral',
    'TransformerConv':   'attention',
    'PNAConv':           'aggregation',
    'ARMAConv':          'spectral',
    'APPNP':             'propagation', 
}

# Option A: top-K by mass coverage (keeps the dominant convs)
quality_set = w_df.head(K_QUALITY)['conv'].tolist()

# Option B: one per family, highest-weight representative (true diversity)
diversity_set, seen_fam = [], set()
for _, row in w_df[w_df['mean_weight'] > MEAN_THRESHOLD].iterrows():
    fam = _family.get(row['conv'], row['conv'])   # use name as family if unknown
    if fam not in seen_fam:
        diversity_set.append(row['conv'])
        seen_fam.add(fam)
    if len(diversity_set) >= K_DIVERSITY:
        break

# --- Print results -----------------------------------------------------------
print(f'Threshold: mean weight > {MEAN_THRESHOLD:.0%}')
print(f'Survivors: {len(survivors)} / {len(experts_df.columns)} convolutions\n')
print(f'{"Rank":<5} {"Convolution":<30} {"Mean wt":>8} {"Family":<16}')
print('-' * 62)
for i, row in w_df.head(20).iterrows():
    fam = _family.get(row['conv'], '-')
    marker = 'A' if row['conv'] in quality_set else ('B' if row['conv'] in diversity_set else ' ')
    marker = 'AB' if row['conv'] in quality_set and row['conv'] in diversity_set else marker
    print(f"{i+1:<5} {row['conv']:<30} {row['mean_weight']:>8.4f} {fam:<16} {marker}")

def _mass(conv_list):
    cols = [list(experts_df.columns).index(c) for c in conv_list]
    return weights_mat[:, cols].sum(axis=1).mean()

print(f'\nOption A : top-{K_QUALITY} by weight:')
for c in quality_set:
    print(f'  {c:<30} [{_family.get(c,"?"):<16}]  mean={w_df.loc[w_df["conv"]==c,"mean_weight"].values[0]:.4f}')
print(f'  Mass coverage: {_mass(quality_set):.1%}')

print(f'\nOption B : one-per-family diversity set (K={K_DIVERSITY}):')
for c in diversity_set:
    print(f'  {c:<30} [{_family.get(c,"?"):<16}]  mean={w_df.loc[w_df["conv"]==c,"mean_weight"].values[0]:.4f}')
print(f'  Mass coverage: {_mass(diversity_set):.1%}')

# --- Plots -------------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

top20  = w_df.head(20)
def _color(name):
    if name in quality_set and name in diversity_set: return '#8e44ad'
    if name in quality_set:   return '#e74c3c'
    if name in diversity_set: return '#2980b9'
    if name in survivors:     return '#e67e22'
    return '#bdc3c7'
colors = [_color(c) for c in top20['conv']]
axes[0].barh(top20['conv'][::-1], top20['mean_weight'][::-1], color=colors[::-1])
axes[0].axvline(MEAN_THRESHOLD, color='black', linestyle='--', linewidth=1,
                label=f'threshold={MEAN_THRESHOLD:.0%}')
axes[0].set_xlabel('Time-averaged MLpol weight')
axes[0].set_title('Expert importance (top-20)')
from matplotlib.patches import Patch
axes[0].legend(handles=[
    Patch(color='#8e44ad', label=f'In both A+B'),
    Patch(color='#e74c3c', label=f'Option A only (top-{K_QUALITY})'),
    Patch(color='#2980b9', label=f'Option B only (diversity-{K_DIVERSITY})'),
    Patch(color='#e67e22', label='Survivor only'),
    Patch(color='#bdc3c7', label='Below threshold'),
], fontsize=7)

dates_w = pd.date_range(start=data_kwargs['day_inf_test'], periods=len(weights_mat), freq='30min')
for conv in quality_set:
    k_idx = list(experts_df.columns).index(conv)
    axes[1].plot(dates_w, weights_mat[:, k_idx], label=conv, linewidth=1.6,
                 linestyle='--' if conv not in diversity_set else '-')
axes[1].set_xlabel('Date (2019)')
axes[1].set_ylabel('MLpol weight')
axes[1].set_title(f'Top-{K_QUALITY} weight trajectories  (solid = also in B)')
axes[1].tick_params(axis='x', rotation=30)
axes[1].legend(fontsize=8, loc='upper right', ncols=2)
plt.tight_layout()
plt.show()

print(f'\nOption A selection (K={K_QUALITY}):')
print(f'  PRUNED_CONVS = {quality_set}')
# Out:
# Threshold: mean weight > 2%
# Survivors: 8 / 48 convolutions
#
# Rank  Convolution                     Mean wt Family
# --------------------------------------------------------------
# 1     LEConv                           0.3534 edge-weighted    AB
# 2     GatedGraphConv                   0.2339 recurrent        AB
# 3     GATConv                          0.1064 -                AB
# 4     APPNP                            0.0870 propagation      AB
# 5     RGATConv                         0.0607 -                AB
# 6     GENConv                          0.0542 aggregation      A
# 7     SAGEConv                         0.0230 aggregation      A
# 8     SGConv                           0.0201 spectral         A
# 9     GCN2Conv                         0.0170 spectral
# 10    SSGConv                          0.0162 spectral
# 11    ARMAConv                         0.0132 spectral
# 12    GATv2Conv                        0.0049 -
# ...

# %% [markdown]
# ## Bottom-Up Aggregation
#
# Instead of aggregating at the national level, we can run MLpol independently per node and then sum. Each regional mixture learns node-specific expert weights, and the national aggregate is the sum of all bottom-level predictions. This is more expressive than top-level aggregation because different regions can favour different experts.

# %%
import numpy as np
import pandas as pd

assert target_nodes is not None, "Run the training loop above first (target_nodes must be saved)."
assert trained_preds, "No predictions available."

T = len(target_national)
step = out_channels                               # 48: one prediction block per day
y_global = target_national.numpy().astype(float)

valid_names = [n for n in trained_preds if n not in (bad_cols if 'bad_cols' in dir() else [])]
N_nodes = target_nodes.shape[0]
print(f"Running per-node MLpol ({N_nodes} nodes x {len(valid_names)} experts)...")

node_agg_preds = []
for node_idx in range(N_nodes):
    y_node = target_nodes[node_idx].numpy().astype(float)
    node_experts = {name: trained_preds[name][node_idx].cpu().detach().numpy()[:T]
                    for name in valid_names}
    node_df = pd.DataFrame(node_experts)
    bad_node = node_df.columns[~np.isfinite(node_df.values).all(axis=0)].tolist()
    if bad_node:
        node_df = node_df.drop(columns=bad_node)
    node_pred = Aggregation(model="MLpol", loss="square").run(
        node_df.values, y_node, block_size=step
    ).prediction_
    node_agg_preds.append(node_pred)

node_agg_preds = np.stack(node_agg_preds, axis=0)     # [N, T]
predictions_agg_bu = node_agg_preds.sum(axis=0)        # national aggregate

print(f"\n{'Method':<28} {'RMSE':>10} {'MAPE':>8}")
print("-" * 50)
for label, pred in [
    ("MLpol (top-level)", predictions_agg),
    ("MLpol (bottom-up)", predictions_agg_bu),
    ("Uniform average", uniform_pred),
    (f"Best individual ({best_name})", experts_df[best_name].values.astype(float)),
]:
    rmse = RMSE(preds=pred, targets=y_global).item()
    mape = 100 * MAPE(preds=pred, targets=y_global).item()
    print(f"{label:<28} {rmse:>10.0f} MW  {mape:>6.2f}%")
# Out:
# Running per-node MLpol (12 nodes x 48 experts)...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/graphtoolbox/aggregation/aggregation.py:390: RuntimeWarning: divide by zero encountered in matmul
#   preds[s:e] = X[s:e] @ p_block
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/graphtoolbox/aggregation/aggregation.py:390: RuntimeWarning: overflow encountered in matmul
#   preds[s:e] = X[s:e] @ p_block
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/graphtoolbox/aggregation/aggregation.py:390: RuntimeWarning: invalid value encountered in matmul
#   preds[s:e] = X[s:e] @ p_block
# Method                             RMSE     MAPE
# --------------------------------------------------
# MLpol (top-level)                   788 MW    1.02%
# MLpol (bottom-up)                   800 MW    1.03%
# Uniform average                     846 MW    1.10%
# ...

# %% [markdown]
# ### Significance of the aggregation rows
#
# The convolution sweep already carries block-bootstrap standard errors; here we attach the same intervals to the three aggregation methods, and re-state the Model Confidence Set over the sweep, so the headline aggregate is reported with the same uncertainty as the rows it improves on. The output is LaTeX-ready for the paper table.

# %%
import numpy as np
from graphtoolbox.evaluation import bootstrap_metric, model_confidence_set, pairwise_dm, diebold_mariano

_y = target_national.numpy() if hasattr(target_national, 'numpy') else np.asarray(target_national)

# 1) Block-bootstrap 95% CI for the three aggregation rows (LaTeX-ready).
_agg = {
    'Uniform average':   uniform_pred,
    'MLpol (bottom-up)': predictions_agg_bu,
    'MLpol (top-level)': predictions_agg,
}
print('% aggregation rows with block-bootstrap standard errors (block=48, 2000 resamples)')
for _name, _p in _agg.items():
    _r = bootstrap_metric(_p, _y, metric='rmse', n_boot=2000, block_len=48, seed=0)
    _m = bootstrap_metric(_p, _y, metric='mape', n_boot=2000, block_len=48, seed=0)
    print(f'{_name:<20} & ${_m.point:.2f} \\pm {_m.se:.2f}$ & ${_r.point:.0f} \\pm {_r.se:.0f}$ \\\\')

# 2) Model Confidence Set over the whole convolution sweep, and DM vs the best.
_nat = {n: p.sum(dim=0) for n, p in trained_preds.items()}
_mcs = model_confidence_set(_nat, _y, loss='squared', alpha=0.10, n_boot=2000, block_len=48, seed=0)
_best = min(_nat, key=lambda n: float(((_nat[n] - _y) ** 2).mean().item()))
_dm = pairwise_dm(_nat, _y, loss='squared', h=48, correction='holm')
_nsig = int((_dm['pvalue_adjusted'][_best].drop(_best) < 0.05).sum())
print(f'\n90% Model Confidence Set: {len(_mcs.included)} of {len(_nat)} convolutions retained.')
print(f'Diebold-Mariano vs the best ({_best}): {_nsig} of {len(_nat) - 1} differ significantly (Holm, 0.05).')
print('MCS members:', ', '.join(sorted(_mcs.included)))

# 3) Paired DM: does the mixture significantly beat the BEST single convolution?
#    Marginal intervals can overlap while the paired test is significant, because
#    the two forecasts are strongly correlated. h=48 matches the daily block.
for _an, _ap in [('MLpol (top-level)', predictions_agg), ('MLpol (bottom-up)', predictions_agg_bu)]:
    _rr = diebold_mariano(_ap, _nat[_best], _y, loss='squared', h=48, names=(_an, _best))
    _verdict = 'significantly below' if (_rr.pvalue < 0.05 and _rr.better == _an) else 'not significantly different'
    print(f'Paired DM {_an} vs {_best}: p={_rr.pvalue:.4f}  ->  {_an} is {_verdict} the best single conv.')

# %% [markdown]
# ## Per-region Error Map
#
# Each French region is coloured by its MAPE on the test set. Comparing panels lets you identify which regions are easy or hard to forecast and whether the bottom-up aggregation reallocates expert weight in a spatially coherent way.

# %%
import numpy as np
from graphtoolbox.utils import plot_node_errors_map
from graphtoolbox.utils import load_kwargs

assert target_nodes is not None, "Run the training loop cell first."

T_map   = target_nodes.shape[1]
true_np = target_nodes.numpy()           # [N, T]
nodes   = graph_dataset_train.nodes      # ordered list of N region names

def _node_mape(pred_np, true_np):
    """Per-node MAPE (%), robust to near-zero targets."""
    denom = np.abs(true_np).mean(axis=1, keepdims=True).clip(min=1e-6)
    return 100 * np.mean(np.abs(pred_np - true_np) / denom, axis=1)

node_errors = {}

# Best individual model
_best_np = trained_preds[best_name].cpu().detach().numpy()[:, :T_map]
node_errors[f'Best model\n({best_name})'] = _node_mape(_best_np, true_np)

# Bottom-up aggregation (requires the cell above to have run)
if 'node_agg_preds' in dir() and node_agg_preds is not None:
    node_errors['MLpol\n(bottom-up)'] = _node_mape(node_agg_preds[:, :T_map], true_np)

plot_node_errors_map(
    node_errors=node_errors,
    nodes=nodes,
    df_pos=load_kwargs(folder_config=graph_dataset_train.folder_config, kwargs='df_pos'),
    metric_label='MAPE (%)',
    cmap='RdYlGn_r',
)

# %% [markdown]
# ## Error diagnostics
#
# Three breakdowns of the signed forecast error (bias = predicted − true) and MAE to identify *when* the model struggles: by half-hour of day, by day of week, and by month.

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np
import pandas as pd

# Config
DIAG_NODES = ['Centre_Val_de_Loire', 'Hauts_de_France']

for DIAG_NODE in DIAG_NODES:
    ni   = list(nodes).index(DIAG_NODE)
    T    = target_nodes.shape[1]
    true = target_nodes[ni].numpy().astype(float)

    preds_diag = {f'Best ({best_name})': trained_preds[best_name][ni].cpu().detach().numpy()[:T]}
    if 'node_agg_preds' in dir() and node_agg_preds is not None:
        preds_diag['MLpol BU'] = node_agg_preds[ni, :T]
    # if 'node_specialists' in dir() and DIAG_NODE in node_specialists:
    #     preds_diag['Specialist'] = node_specialists[DIAG_NODE][:T]

    dates    = pd.Series(pd.date_range(start=data_kwargs['day_inf_test'], periods=T, freq='30min'))
    instants = dates.dt.hour * 2 + dates.dt.minute // 30
    dow      = dates.dt.dayofweek
    months   = dates.dt.month

    DOW_LABELS   = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
    MONTH_LABELS = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    INST_LABELS  = [f'{h:02d}:{m:02d}' for h in range(24) for m in (0, 30)]

    colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds_diag)]

    fig, axes = plt.subplots(2, 3, figsize=(16, 8))
    fig.suptitle(f'Error diagnostics: {DIAG_NODE.replace("_", " ")}',
                fontsize=14, fontweight='bold')

    groups = [
        (instants,  np.arange(48),  INST_LABELS,  'Half-hour of day'),
        (dow,       np.arange(7),   DOW_LABELS,   'Day of week'),
        (months-1,  np.arange(12),  MONTH_LABELS, 'Month'),
    ]

    for col, (idx, bins, labels, xlabel) in enumerate(groups):
        ax_bias = axes[0, col]
        ax_mae  = axes[1, col]

        bar_w   = 0.8 / max(len(preds_diag), 1)
        offsets = np.linspace(-0.4 + bar_w/2, 0.4 - bar_w/2, len(preds_diag))

        for (name, pred), color, offset in zip(preds_diag.items(), colors, offsets):
            err  = pred - true
            bias = np.array([err[idx == b].mean() if (idx == b).any() else np.nan for b in bins])
            mape  = np.array([100 * np.abs(err[idx == b]).mean() / (np.abs(true[idx == b]).mean() + 1e-6)
                              if (idx == b).any() else np.nan for b in bins])
            x = bins + offset
            ax_bias.bar(x, bias, width=bar_w * 0.9, color=color, alpha=0.75, label=name)
            ax_mae.bar( x, mape,  width=bar_w * 0.9, color=color, alpha=0.75, label=name)

        for ax, ylabel, title_suffix in [
            (ax_bias, 'Bias (MW)',  'Signed bias'),
            (ax_mae,  'MAPE (%)',   'MAPE'),
        ]:
            ax.axhline(0, color='black', linewidth=0.7, linestyle='--')
            ax.set_xticks(bins)
            if len(labels) == 48:
                ax.set_xticklabels([l if i % 4 == 0 else '' for i, l in enumerate(labels)],
                                rotation=45, ha='right', fontsize=7)
            else:
                ax.set_xticklabels(labels, fontsize=9)
            ax.set_ylabel(ylabel, fontsize=9)
            ax.set_title(f'{title_suffix} by {xlabel}', fontsize=10)
            ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda v, _: f'{v:,.1f}'))
            if col == 0:
                ax.legend(fontsize=8, loc='upper left')

    plt.tight_layout()
    plt.show()
