# %% [markdown]
# # GraphToolbox - Load Example

# %% [markdown]
# This notebook was succesfully tested with Python 3.11.9.

# %% [markdown]
# ## Importing libraries

# %% [markdown]
# Importing all libraries should take a minute or two.

# %%
# General libraries
import gc
import torch
from torch_geometric.nn.conv import *
from torch_geometric.nn.models import *
from torch_geometric import seed_everything

# GraphToolbox
from graphtoolbox.data.dataset import *
from graphtoolbox.models.gnn import *
from graphtoolbox.optim.optimizer import *
from graphtoolbox.training.trainer import Trainer
from graphtoolbox.utils.attention import *
from graphtoolbox.utils.helper_functions import *
from graphtoolbox.utils.visualizations import *

# Autoreload
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CUDA or not CUDA ?

# %%
print('CUDA'*(torch.cuda.is_available())+(1-torch.cuda.is_available())*'not CUDA')
# Out:
# not CUDA

# %% [markdown]
# ## Instantiating graph objects

# %% [markdown]
# There are two graph objects in the following cell:
#
# - a **DataClass** object, which is always defined by three arguments: `path_train` which is the path to the training dataset, `path_test` which is the path to the testing dataset, and `folder_config` which is the folder of your config file. There are additional keyword arguments if you want to specify a validation set. A DataClass object allows to manipulate the dataframes easily.
#
# - a **GraphDataset** object, which is always defined by two arguments: `data` which is an instance of DataClass, `period` which specifies if it is a train., val. or test. dataset. If the dataset is for validation or test, then you will need to specify scalers: `scalers_feat` to scale the features, and `scalers_target` to scale the target. There are additional keyword arguments that you can find in the documentation. A GraphDataset object allows to manipulate the data as graph objects in the PyG format.

# %%
data_kwargs = {
    'node_var': 'Region',
    'features_to_lag': {'load': (1, 48), 'temp': (-47, -1)},
    'dummies': ['Instant', 'RegionInt', 'JourSemaine', 'DayType', 'offset'],
    'day_inf_train': '2015-01-01',
    'day_sup_train': '2018-01-01',
    'day_inf_val': '2018-01-01',
    'day_sup_val': '2018-12-31',
    'day_inf_test': '2019-01-01',
    'day_sup_test': '2019-12-31'
}

dataset_kwargs = {
    'batch_size': 32,
    'adj_matrix': 'dtw',
    'features_base': ['temp', 'nebu', 'wind', 'tempMax', 'tempMin', 'Posan', 'Instant', 'RegionInt', 'JourSemaine', 'JourFerie', 'offset', 'DayType', 'Weekend', 'temp_liss_fort', 'temp_liss_faible'] + [f'load_l{t}' for t in range(1, 48+1)] + [f'temp_l{t}' for t in range(-47, -1+1)],
    'target_base': 'load',
}

out_channels = 48
data = DataClass(path_train='./train.csv', 
                 path_test='./test.csv', 
                 data_kwargs=data_kwargs,
                 folder_config='.')

graph_dataset_train = GraphDataset(data=data, period='train', 
                                    graph_folder='../graph_representations',
                                    dataset_kwargs=dataset_kwargs,
                                    out_channels=out_channels)
graph_dataset_val = GraphDataset(data=data, period='val', 
                                    scalers_feat=graph_dataset_train.scalers_feat, 
                                    scalers_target=graph_dataset_train.scalers_target,
                                    graph_folder='../graph_representations',
                                    dataset_kwargs=dataset_kwargs,
                                    out_channels=out_channels)
graph_dataset_test = GraphDataset(data=data, period='test',
                                     scalers_feat=graph_dataset_train.scalers_feat, 
                                     scalers_target=graph_dataset_train.scalers_target,
                                     graph_folder='../graph_representations',
                                     dataset_kwargs=dataset_kwargs,
                                    out_channels=out_channels)

# %%
graph_dataset_test[0]
# Out:
# Data(x=[12, 183], edge_index=[2, 142], y=[12, 48], edge_weight=[142], mask_X=[12, 183], mask_y=[12, 48], y_scaled=[12, 48])

# %%
import torch
import inspect
from torch_geometric.nn import conv as pyg_conv

print("Auto-testing all torch_geometric.nn.conv layers\n")

num_nodes = 15
x = torch.randn(num_nodes, 16)
edge_index = torch.randint(0, num_nodes, (2, 40))

success, fail, skipped = [], [], []

skip_keywords = [
    "CuGraph",  
    "Hetero", "HAN", "HGT", "HEAT",  
    "Point", "PPF", "Hypergraph", 
]

for name, cls in inspect.getmembers(pyg_conv, inspect.isclass):
    if not name.endswith("Conv"):
        continue
    if any(k in name for k in skip_keywords):
        print(f"⏩ {name:<25} -> skipped (unsupported on macOS)")
        skipped.append(name)
        continue

    try:
        model = myGNN(
            in_channels=16,
            hidden_channels=32,
            out_channels=1,
            num_layers=2,
            conv_class=cls,
        )
        with torch.no_grad():
            out = model(x, edge_index)

        if not torch.is_tensor(out):
            raise TypeError("Output is not a tensor")
        success.append((name, tuple(out.shape)))
        print(f"✅ {name:<25} -> output {tuple(out.shape)}")

    except Exception as e:
        msg = str(e).splitlines()[0] if str(e) else "<no message>"
        if "pylibcugraphops" in msg:
            print(f"⏩ {name:<25} -> skipped (requires RAPIDS CUDA libs)")
            skipped.append(name)
            continue
        fail.append((name, type(e).__name__, msg))
        print(f"❌ {name:<25} -> {type(e).__name__}: {msg}")

print(f"\n✅ Successful: {len(success)}")
print(f"❌ Failed:     {len(fail)}")
print(f"⏩ Skipped:    {len(skipped)}")

if fail:
    print("\nExamples of failures:")
    for n, err, msg in fail[:10]:
        print(f"  - {n}: {err} ({msg})")
# Out:
# Auto-testing all torch_geometric.nn.conv layers
#
# ✅ AGNNConv                  -> output (15, 1)
# ✅ ARMAConv                  -> output (15, 1)
# ✅ AntiSymmetricConv         -> output (15, 1)
# ✅ CGConv                    -> output (15, 1)
# ✅ ChebConv                  -> output (15, 1)
# ✅ ClusterGCNConv            -> output (15, 1)
# ⏩ CuGraphGATConv            -> skipped (unsupported on macOS)
# ⏩ CuGraphRGCNConv           -> skipped (unsupported on macOS)
# ⏩ CuGraphSAGEConv           -> skipped (unsupported on macOS)
# ✅ DNAConv                   -> output (15, 1)
# ✅ DirGNNConv                -> output (15, 1)
# ✅ DynamicEdgeConv           -> output (15, 1)
# ✅ ECConv                    -> output (15, 1)
# ✅ EGConv                    -> output (15, 1)
# ✅ EdgeConv                  -> output (15, 1)
# ✅ FAConv                    -> output (15, 1)
# ✅ FastRGCNConv              -> output (15, 1)
# ✅ FeaStConv                 -> output (15, 1)
# ✅ FiLMConv                  -> output (15, 1)
# ❌ FusedGATConv              -> ModuleNotFoundError: No module named 'dgNN'
# ✅ GATConv                   -> output (15, 1)
# ✅ GATv2Conv                 -> output (15, 1)
# ✅ GCN2Conv                  -> output (15, 1)
# ✅ GCNConv                   -> output (15, 1)
# ✅ GENConv                   -> output (15, 1)
# ✅ GINConv                   -> output (15, 1)
# ✅ GINEConv                  -> output (15, 1)
# ✅ GMMConv                   -> output (15, 1)
# ✅ GPSConv                   -> output (15, 1)
# ✅ GatedGraphConv            -> output (15, 1)
# ✅ GeneralConv               -> output (15, 1)
# ✅ GraphConv                 -> output (15, 1)
# ✅ GravNetConv               -> output (15, 1)
# ⏩ HANConv                   -> skipped (unsupported on macOS)
# ⏩ HEATConv                  -> skipped (unsupported on macOS)
# ⏩ HGTConv                   -> skipped (unsupported on macOS)
# ⏩ HeteroConv                -> skipped (unsupported on macOS)
# ⏩ HypergraphConv            -> skipped (unsupported on macOS)
# ✅ LEConv                    -> output (15, 1)
# ✅ LGConv                    -> output (15, 1)
# ✅ MFConv                    -> output (15, 1)
# ✅ MixHopConv                -> output (15, 1)
# ✅ NNConv                    -> output (15, 1)
# ✅ PANConv                   -> output (15, 1)
# ✅ PDNConv                   -> output (15, 1)
# ✅ PNAConv                   -> output (15, 1)
# ⏩ PPFConv                   -> skipped (unsupported on macOS)
# ⏩ PointConv                 -> skipped (unsupported on macOS)
# ⏩ PointGNNConv              -> skipped (unsupported on macOS)
# ⏩ PointNetConv              -> skipped (unsupported on macOS)
# ⏩ PointTransformerConv      -> skipped (unsupported on macOS)
# ✅ RGATConv                  -> output (15, 1)
# ✅ RGCNConv                  -> output (15, 1)
# ✅ ResGatedGraphConv         -> output (15, 1)
# ✅ SAGEConv                  -> output (15, 1)
# ✅ SGConv                    -> output (15, 1)
# ✅ SSGConv                   -> output (15, 1)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_sparse/matmul.py:97: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:55.)
#   C = torch.sparse.mm(A, B)
# ✅ SignedConv                -> output (15, 1)
# ✅ SimpleConv                -> output (15, 1)
# ✅ SplineConv                -> output (15, 1)
# ✅ SuperGATConv              -> output (15, 1)
# ✅ TAGConv                   -> output (15, 1)
# ✅ TransformerConv           -> output (15, 1)
# ✅ WLConv                    -> output (15, 1)
# ✅ XConv                     -> output (15, 1)
#
# ✅ Successful: 51
# ❌ Failed:     1
# ⏩ Skipped:    13
#
# Examples of failures:
#   - FusedGATConv: ModuleNotFoundError (No module named 'dgNN')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/nn/conv/spline_conv.py:133: UserWarning: We do not recommend using the non-optimized CPU version of `SplineConv`. If possible, please move your data to GPU.
#   warnings.warn(

# %% [markdown]
# ## Training a graph model

# %% [markdown]
# To train your graph models, the GraphToolbox has a training module. To use it, you need to instantiate a `Trainer` object which takes four arguments: `model` which is a graph model, and three GraphDataset objects `dataset_train`, `dataset_val` and `dataset_test`. There are other keyword arguments that you can find in the documentation. Then, when your trainer is instantiated, you can use the `train()` method. Note that if there is a pre-trained model with the same parameters, the trainer will automatically load the pre-trained weights (if you want to train another model with the same parameters, you will need to enforce `force_training=True` in the `train()` method).

# %%
gc.collect()
torch.cuda.empty_cache()
seed_everything(seed=42)

# conv_class = GATv2Conv
# conv_kwargs = {'heads': 2}
# params = {'num_layers': 2, 'hidden_channels': 359, 'lr': 4e-4, 'batch_size': 32, 'adj_matrix': 'space', 'lam_reg': 0}

# conv_class = GATConv
# conv_kwargs = {'heads': 2}
# params = {'num_layers': 3, 'hidden_channels': 364, 'lr': 1e-3, 'batch_size': 16, 'adj_matrix': 'gl3sr', 'lam_reg': 0}

# conv_class = ChebConv
# conv_kwargs = {'K': 3}
# params = {'num_layers': 1, 'hidden_channels': 249, 'lr': 6e-4, 'batch_size': 16, 'adj_matrix': 'distsplines', 'lam_reg': 0}

conv_class = APPNP
conv_kwargs = {'K': 1, 'alpha': .94}
params = {'num_layers': 1, 'hidden_channels': 106, 'lr': 2e-3, 'batch_size': 16, 'adj_matrix': 'space'}

graph_dataset_train._set_adj_matrix(adj_matrix=params['adj_matrix'])
graph_dataset_val._set_adj_matrix(adj_matrix=params['adj_matrix'])
graph_dataset_test._set_adj_matrix(adj_matrix=params['adj_matrix'])

model = myGNN(
    in_channels=graph_dataset_train.num_node_features,
    num_layers=params["num_layers"],
    hidden_channels=params["hidden_channels"],
    out_channels=out_channels,
    conv_class=conv_class,
    conv_kwargs=conv_kwargs
)


trainer = Trainer(
    model=model,
    dataset_train=graph_dataset_train,
    dataset_val=graph_dataset_val,
    dataset_test=graph_dataset_test,
    batch_size=params["batch_size"],
    model_kwargs={'lr': params["lr"], 'num_epochs': 300},
    reconcile=True,
    top_level_model='xgb',
    lam_reg=0
)

pred_model_test, target_test, edge_index, attention_weights = trainer.train(
    plot_loss=True,
    force_training=False,
    save=True,
    patience=75
)
trainer.evaluate()
# Out:
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
# MAPE on test set: 1.3141 %
# RMSE on test set: 1003.6511 MW

# %% [markdown]
# To visualize your predictions for each node, you can use the `plot_nodes()` method.

# %%
plot_nodes(true=target_test, pred=pred_model_test, graph_dataset=graph_dataset_test)

# %%
for i in range(pred_model_test.shape[0]-1):
    region = graph_dataset_train.nodes[i]
    preds = pred_model_test[i].cpu().detach()
    targets = target_test[i]
    print(f'RMSE {region} = {torch.round(RMSE(preds=preds, targets=targets))} MW')
    print(f'BIAS {region} = {torch.round(BIAS(preds=preds, targets=targets))} MW')
    print(f'MAPE {region} = {100*(MAPE(preds=preds, targets=targets))} %')

print(f'RMSE national = {torch.round(RMSE(preds=pred_model_test.sum(axis=0).cpu().detach(), targets=target_test.sum(axis=0)))} MW')
print(f'BIAS national = {torch.round(BIAS(preds=pred_model_test.sum(axis=0).cpu().detach(), targets=target_test.sum(axis=0)))} MW')
print(f'MAPE national = {100*(MAPE(preds=pred_model_test.sum(axis=0).cpu().detach(), targets=target_test.sum(axis=0)))} %')
# Out:
# RMSE Auvergne_Rhone_Alpes = 197.0 MW
# BIAS Auvergne_Rhone_Alpes = -43.0 MW
# MAPE Auvergne_Rhone_Alpes = 2.01753306388855 %
# RMSE Bourgogne_Franche_Comte = 85.0 MW
# BIAS Bourgogne_Franche_Comte = 0.0 MW
# MAPE Bourgogne_Franche_Comte = 2.5642809867858887 %
# RMSE Bretagne = 82.0 MW
# BIAS Bretagne = 14.0 MW
# MAPE Bretagne = 2.230009078979492 %
# RMSE Centre_Val_de_Loire = 111.0 MW
# BIAS Centre_Val_de_Loire = -8.0 MW
# MAPE Centre_Val_de_Loire = 3.7050228118896484 %
# RMSE Grand_Est = 177.0 MW
# BIAS Grand_Est = 42.0 MW
# MAPE Grand_Est = 2.346269130706787 %
# RMSE Hauts_de_France = 144.0 MW
# BIAS Hauts_de_France = -24.0 MW
# MAPE Hauts_de_France = 1.8745256662368774 %
# RMSE Ile_de_France = 263.0 MW
# BIAS Ile_de_France = -86.0 MW
# MAPE Ile_de_France = 2.6296024322509766 %
# RMSE Normandie = 98.0 MW
# BIAS Normandie = -39.0 MW
# MAPE Normandie = 2.3244540691375732 %
# RMSE Nouvelle_Aquitaine = 156.0 MW
# BIAS Nouvelle_Aquitaine = -10.0 MW
# MAPE Nouvelle_Aquitaine = 2.427720546722412 %
# RMSE Occitanie = 141.0 MW
# BIAS Occitanie = -32.0 MW
# MAPE Occitanie = 2.410414695739746 %
# RMSE Pays_de_la_Loire = 110.0 MW
# BIAS Pays_de_la_Loire = 17.0 MW
# MAPE Pays_de_la_Loire = 2.5256478786468506 %
# RMSE national = 1004.0 MW
# BIAS national = -205.0 MW
# MAPE national = 1.314124345779419 %

# %% [markdown]
# # Optimizing a model

# %% [markdown]
# GNNs are a category of models that have a lot of hyperparameters which need to be tuned. The optimization module of the GraphToolbox uses Optuna, which is a well known optimization framework especially in the field of deep-learning.

# %%
optim_base = {
    'num_layers': (1, 5),
    'hidden_channels': (32, 512),
    'lr': (1e-5, 1e-1),
}

_with_heads = optim_base | {'heads': (1, 5)}
_with_K     = optim_base | {'K': (1, 10)}

optim_kwargs_conv = {
    # GCN / Spectral
    'GCNConv':           optim_base,
    'ChebConv':          _with_K,
    'SGConv':            _with_K,
    'SSGConv':           optim_base | {'alpha': (0.0, 1.0)},
    'LGConv':            optim_base,
    'GCN2Conv':          optim_base | {'alpha': (0.0, 1.0)},
    'ClusterGCNConv':    optim_base,
    'FAConv':            optim_base,
    # Attention-based
    'GATConv':           _with_heads,
    'GATv2Conv':         _with_heads,
    'SuperGATConv':      _with_heads,
    'TransformerConv':   _with_heads,
    'AGNNConv':          optim_base,
    'DNAConv':           optim_base | {'heads': (1, 5), 'K': (1, 10)},
    # MPNN / Aggregation
    'SAGEConv':          optim_base,
    'GENConv':           optim_base,
    'GraphConv':         optim_base,
    'MFConv':            optim_base,
    'LEConv':            optim_base,
    'SimpleConv':        optim_base,
    'EGConv':            optim_base,
    'GravNetConv':       optim_base,
    # MLP-based (GIN-style)
    'GINConv':           optim_base,
    'GINEConv':          optim_base,
    # Edge-conditioned
    'NNConv':            optim_base,
    'ECConv':            optim_base,
    'CGConv':            optim_base,
    'GMMConv':           optim_base,
    'GeneralConv':       _with_heads,
    'XConv':             optim_base,
    # Recurrent / Gated
    'GatedGraphConv':    optim_base,
    'ARMAConv':          optim_base,
    'TAGConv':           _with_K,
    # Residual / Deep
    'DirGNNConv':        optim_base | {'alpha': (0.0, 1.0)},
    'AntiSymmetricConv': optim_base | {'gamma': (0.01, 1.0), 'epsilon': (0.01, 1.0)},
    'FiLMConv':          optim_base,
    'ResGatedGraphConv': optim_base,
    'PDNConv':           optim_base,
    # Spectral / Poly
    'MixHopConv':        optim_base,
    'GPSConv':           optim_base,
    'FeaStConv':         optim_base,
    'PANConv':           optim_base,
    # Dynamic aggregators
    'PNAConv':           optim_base,
    'EdgeConv':          optim_base,
    'DynamicEdgeConv':   optim_base | {'k': (3, 15)},
    # Relational
    'RGCNConv':          optim_base,
    'RGATConv':          _with_heads,
    'FastRGCNConv':      optim_base,
    # Graph-level
    'WLConv':            optim_base,
    'SignedConv':        optim_base,
    # APPNP
    'APPNP':             _with_K | {'alpha': (0.5, 1.0)},
}

conv_class = SuperGATConv
optim_kwargs = optim_kwargs_conv[conv_class.__name__]
optimizer = Optimizer(model=myGNN,
                      dataset_train=graph_dataset_train,
                      dataset_val=graph_dataset_val,
                      conv_class=conv_class,
                      num_epochs=100,
                      optim_kwargs=optim_kwargs)
optimizer.optimize(n_trials=200)
# Out:
# [I 2026-06-01 11:45:47,644] A new study created in memory with name: myGNN_hpo
# 100%|██████████| 100/100 [00:15<00:00,  6.36it/s]
# [I 2026-06-01 11:46:03,583] Trial 0 finished with value: 0.12054118514060974 and parameters: {'num_layers': 5, 'hidden_channels': 158, 'lr': 1.252686641350147e-05, 'heads': 2, 'batch_size': 64, 'adj_matrix': 'correlation'}. Best is trial 0 with value: 0.12054118514060974.
# 100%|██████████| 100/100 [00:02<00:00, 49.17it/s]
# [I 2026-06-01 11:46:05,728] Trial 1 finished with value: 0.0028742090798914433 and parameters: {'num_layers': 3, 'hidden_channels': 125, 'lr': 0.003243233484507086, 'heads': 4, 'batch_size': 16, 'adj_matrix': 'eye'}. Best is trial 1 with value: 0.0028742090798914433.
# 100%|██████████| 100/100 [00:08<00:00, 11.37it/s]
# [I 2026-06-01 11:46:14,578] Trial 2 finished with value: 0.0031197057105600834 and parameters: {'num_layers': 1, 'hidden_channels': 460, 'lr': 0.017415089124778623, 'heads': 4, 'batch_size': 128, 'adj_matrix': 'eye'}. Best is trial 1 with value: 0.0028742090798914433.
# 100%|██████████| 100/100 [00:01<00:00, 68.04it/s]
# [I 2026-06-01 11:46:16,171] Trial 3 finished with value: 0.0030119025614112616 and parameters: {'num_layers': 2, 'hidden_channels': 93, 'lr': 0.03132892232495688, 'heads': 1, 'batch_size': 64, 'adj_matrix': 'eye'}. Best is trial 1 with value: 0.0028742090798914433.
# 100%|██████████| 100/100 [00:09<00:00, 10.60it/s]
# [I 2026-06-01 11:46:25,678] Trial 4 finished with value: 0.006731491535902023 and parameters: {'num_layers': 5, 'hidden_channels': 88, 'lr': 0.04045686750212417, 'heads': 4, 'batch_size': 32, 'adj_matrix': 'precision'}. Best is trial 1 with value: 0.0028742090798914433.
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-06-01 11:46:25,903] Trial 5 pruned.
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-06-01 11:46:26,143] Trial 6 pruned.
#  76%|███████▌  | 76/100 [00:38<00:12,  1.99it/s]
# [I 2026-06-01 11:47:04,319] Trial 7 pruned.
#  10%|█         | 10/100 [00:00<00:03, 25.03it/s]
# [I 2026-06-01 11:47:04,828] Trial 8 pruned.
# 100%|██████████| 100/100 [00:02<00:00, 41.06it/s]
# [I 2026-06-01 11:47:07,310] Trial 9 finished with value: 0.002697671763598919 and parameters: {'num_layers': 4, 'hidden_channels': 33, 'lr': 0.0015325276296561502, 'heads': 5, 'batch_size': 64, 'adj_matrix': 'eye'}. Best is trial 9 with value: 0.002697671763598919.
#   1%|          | 1/100 [00:00<00:05, 17.94it/s]
# [I 2026-06-01 11:47:07,417] Trial 10 pruned.
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-06-01 11:47:07,578] Trial 11 pruned.
# 100%|██████████| 100/100 [00:01<00:00, 75.54it/s]
# [I 2026-06-01 11:47:09,168] Trial 12 finished with value: 0.002705127466470003 and parameters: {'num_layers': 4, 'hidden_channels': 32, 'lr': 0.001327696130831603, 'heads': 5, 'batch_size': 16, 'adj_matrix': 'eye'}. Best is trial 9 with value: 0.002697671763598919.
#  41%|████      | 41/100 [00:06<00:08,  6.59it/s]
# [I 2026-06-01 11:47:15,573] Trial 13 pruned.
# 100%|██████████| 100/100 [00:08<00:00, 12.38it/s]
# [I 2026-06-01 11:47:23,766] Trial 14 finished with value: 0.0022099213674664497 and parameters: {'num_layers': 4, 'hidden_channels': 207, 'lr': 0.00023767494087213216, 'heads': 5, 'batch_size': 64, 'adj_matrix': 'eye'}. Best is trial 14 with value: 0.0022099213674664497.
#   1%|          | 1/100 [00:00<00:13,  7.30it/s]
# [I 2026-06-01 11:47:24,020] Trial 15 pruned.
#   5%|▌         | 5/100 [00:01<00:30,  3.09it/s]
# [I 2026-06-01 11:47:25,732] Trial 16 pruned.
#   1%|          | 1/100 [00:00<01:21,  1.21it/s]
# [I 2026-06-01 11:47:26,633] Trial 17 pruned.
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-06-01 11:47:26,930] Trial 18 pruned.
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-06-01 11:47:27,592] Trial 19 pruned.
#   1%|          | 1/100 [00:00<00:16,  6.15it/s]
# [I 2026-06-01 11:47:27,830] Trial 20 pruned.
# 100%|██████████| 100/100 [00:02<00:00, 43.69it/s]
# [I 2026-06-01 11:47:30,173] Trial 21 finished with value: 0.0024495969992130995 and parameters: {'num_layers': 4, 'hidden_channels': 90, 'lr': 0.0012094648076723911, 'heads': 5, 'batch_size': 16, 'adj_matrix': 'eye'}. Best is trial 14 with value: 0.0022099213674664497.
#   6%|▌         | 6/100 [00:00<00:02, 37.33it/s]
# [I 2026-06-01 11:47:30,384] Trial 22 pruned.
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-06-01 11:47:30,486] Trial 23 pruned.
#   1%|          | 1/100 [00:00<00:30,  3.19it/s]
# [I 2026-06-01 11:47:30,852] Trial 24 pruned.
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-06-01 11:47:31,130] Trial 25 pruned.
#  79%|███████▉  | 79/100 [00:03<00:00, 28.06it/s]

# %% [markdown]
# ## Training all working convolutions
#
# This section trains a `myGNN` with shared default hyperparameters for every PyG convolution that passes the compatibility test above. Predictions are cached on disk so you can resume without retraining.

# %%
import gc
import inspect
import os
import re
from torch_geometric.nn import conv as pyg_conv

_skip_keywords = ['CuGraph', 'GPSConv', 'Hetero', 'HAN', 'HGT', 'HEAT', 'Point', 'PPF', 'Hypergraph', 'Spline', 'XConv', 'WLConv']

ALL_CONV_CLASSES = {}
_x_probe = torch.randn(15, graph_dataset_train.num_node_features)
_ei_probe = torch.randint(0, 15, (2, 40))

for _name, _cls in inspect.getmembers(pyg_conv, inspect.isclass):
    if not _name.endswith('Conv'):
        continue
    if any(k in _name for k in _skip_keywords):
        continue
    try:
        _m = myGNN(
            in_channels=graph_dataset_train.num_node_features,
            hidden_channels=32,
            out_channels=out_channels,
            num_layers=2,
            conv_class=_cls,
        )
        with torch.no_grad():
            _out = _m(_x_probe, _ei_probe)
        if not torch.is_tensor(_out):
            raise ValueError
        del _m
        ALL_CONV_CLASSES[_name] = _cls
    except (ImportError, ModuleNotFoundError):
        pass
    except Exception:
        pass

del _x_probe, _ei_probe
print(f"Working convolutions ({len(ALL_CONV_CLASSES)}):")
for _n in ALL_CONV_CLASSES:
    print(f"  {_n}")
# Out:
# Working convolutions (47):
#   AGNNConv
#   ARMAConv
#   AntiSymmetricConv
#   CGConv
#   ChebConv
#   ClusterGCNConv
#   DNAConv
#   DirGNNConv
#   DynamicEdgeConv
#   ECConv
#   EGConv
#   EdgeConv
#   FAConv
#   FastRGCNConv
#   FeaStConv
#   FiLMConv
#   GATConv
#   GATv2Conv
#   GCN2Conv
#   GCNConv
#   GENConv
#   GINConv
#   GINEConv
#   GMMConv
#   GatedGraphConv
#   GeneralConv
#   GraphConv
#   GravNetConv
#   LEConv
#   LGConv
#   MFConv
#   MixHopConv
#   NNConv
#   PANConv
#   PDNConv
#   PNAConv
#   RGATConv
#   RGCNConv
#   ResGatedGraphConv
#   SAGEConv
#   SGConv
#   SSGConv
#   SignedConv
#   SimpleConv
#   SuperGATConv
#   TAGConv
#   TransformerConv

# %%
import json as _json
from inspect import signature as _sig, Parameter as _Param

# Params that belong to myGNN.__init__ directly (excluding fixed inputs and **kwargs)
_GNN_CTOR_PARAMS = {
    p.name for p in _sig(myGNN.__init__).parameters.values()
    if p.name not in ('self', 'in_channels', 'out_channels', 'conv_class', 'conv_kwargs')
    and p.kind not in (_Param.VAR_KEYWORD, _Param.VAR_POSITIONAL)
}
# Params consumed at the sweep level, not forwarded to the model constructor
_SWEEP_LEVEL = {'num_layers', 'hidden_channels', 'lr', 'batch_size', 'adj_matrix'}

def _resolve_params(conv_name):
    """Return (run_params, model_kw, conv_kw, source) for a convolution.

    Loads ./results_optim_{conv_name}/myGNN_best.json when available and
    falls back to LOOP_PARAMS otherwise.

    run_params  -- num_layers, hidden_channels, lr, batch_size, adj_matrix,
                   num_epochs, patience (always taken from LOOP_PARAMS for the last two)
    model_kw    -- extra myGNN constructor params found in best (e.g. heads)
    conv_kw     -- conv-specific params found in best (e.g. K, alpha, k)
    source      -- 'optimized' or 'default'
    """
    json_path = f'./results_optim_{conv_name}/myGNN_best.json'
    if os.path.exists(json_path):
        with open(json_path) as _f:
            best = _json.load(_f)['params']
        source = 'optimized'
    else:
        best = {}
        source = 'default'

    run_params = {
        'num_layers':    int(best.get('num_layers',    LOOP_PARAMS['num_layers'])),
        'hidden_channels': int(best.get('hidden_channels', LOOP_PARAMS['hidden_channels'])),
        'lr':            float(best.get('lr',            LOOP_PARAMS['lr'])),
        'batch_size':    int(best.get('batch_size',    LOOP_PARAMS['batch_size'])),
        'adj_matrix':    best.get('adj_matrix',    LOOP_PARAMS['adj_matrix']),
        'num_epochs':    LOOP_PARAMS['num_epochs'],
        'patience':      LOOP_PARAMS['patience'],
    }
    # Extra model-constructor params not already covered by run_params (e.g. heads)
    model_kw = {k: v for k, v in best.items()
                if k in _GNN_CTOR_PARAMS and k not in _SWEEP_LEVEL}
    # Conv-specific params (e.g. K, alpha, k, gamma, epsilon)
    conv_kw  = {k: v for k, v in best.items()
                if k not in _GNN_CTOR_PARAMS and k not in _SWEEP_LEVEL}

    return run_params, model_kw, conv_kw, source


# Default hyperparameters for the sweep (used when no optimized params exist)
LOOP_PARAMS = {
    'num_layers':     2,
    'hidden_channels': 64,
    'lr':             1e-3,
    'batch_size':     32,
    'adj_matrix':     'dtw',
    'num_epochs':     200,
    'patience':       30,
    'reconcile':      True,
}
RESULTS_DIR = './results_all_convolutions'
os.makedirs(RESULTS_DIR, exist_ok=True)

# Track whether LOOP_PARAMS changed since the last run.
# Legacy caches (no sidecar) are treated as stale when defaults changed.
_loop_state_path = os.path.join(RESULTS_DIR, '_loop_params.json')
_last_loop_params = None
if os.path.exists(_loop_state_path):
    with open(_loop_state_path) as _lf:
        _last_loop_params = _json.load(_lf)
_loop_params_unchanged = (_last_loop_params is None or _last_loop_params == LOOP_PARAMS)
with open(_loop_state_path, 'w') as _lf:
    _json.dump(LOOP_PARAMS, _lf)

trained_preds  = {}      # conv_name -> [num_nodes, T] tensor
target_national = None   # [T] float tensor, same for every model
target_nodes   = None   # [num_nodes, T] tensor, for per-node Opera
failed_loop    = {}

_target_path       = os.path.join(RESULTS_DIR, 'target.pt')
_target_nodes_path = os.path.join(RESULTS_DIR, 'target_nodes.pt')
_current_adj  = LOOP_PARAMS['adj_matrix']

# Set initial adjacency matrix
for _ds in [graph_dataset_train, graph_dataset_val, graph_dataset_test]:
    _ds._set_adj_matrix(adj_matrix=_current_adj)

for conv_name, cls in ALL_CONV_CLASSES.items():
    pred_path = os.path.join(RESULTS_DIR, f'{conv_name}.pt')

    # --- cache hit (only valid if params match) ---
    _params_path = os.path.join(RESULTS_DIR, f'{conv_name}_params.json')
    _params, _model_kw, _conv_kw, _src = _resolve_params(conv_name)
    _current_params_key = {**_params, **_model_kw, **_conv_kw,
                        'reconcile': LOOP_PARAMS['reconcile']}
    if os.path.exists(pred_path) and os.path.exists(_params_path):
        with open(_params_path) as _pf:
            _stored = _json.load(_pf)
        _cache_valid = (_stored == _current_params_key)
    else:
        # No sidecar: legacy cache. Valid only when still on default params
        # AND LOOP_PARAMS itself has not changed since the last run.
        _cache_valid = os.path.exists(pred_path) and _src == 'default' and _loop_params_unchanged
    if _cache_valid:
        trained_preds[conv_name] = torch.load(pred_path, weights_only=False)
        if target_national is None and os.path.exists(_target_path):
            target_national = torch.load(_target_path, weights_only=False)
        if target_nodes is None and os.path.exists(_target_nodes_path):
            target_nodes = torch.load(_target_nodes_path, weights_only=False)
        print(f'⏩ {conv_name:<25} loaded from cache  [{_src}]')
        continue

    print(f'\n🔄 Training {conv_name}... [{_src}]')
    if _src == 'optimized':
        _detail = (f'   layers={_params["num_layers"]}  hidden={_params["hidden_channels"]}'
                   f'  lr={_params["lr"]:.2e}  batch={_params["batch_size"]}'
                   f'  adj={_params["adj_matrix"]}')
        if _model_kw: _detail += f'  model_kw={_model_kw}'
        if _conv_kw:  _detail += f'  conv_kw={_conv_kw}'
        print(_detail)
    seed_everything(42)
    gc.collect()

    # Switch adjacency matrix when the optimized params require a different one
    if _params['adj_matrix'] != _current_adj:
        for _ds in [graph_dataset_train, graph_dataset_val, graph_dataset_test]:
            _ds._set_adj_matrix(adj_matrix=_params['adj_matrix'])
        _current_adj = _params['adj_matrix']

    try:
        _model = myGNN(
            in_channels=graph_dataset_train.num_node_features,
            num_layers=_params['num_layers'],
            hidden_channels=_params['hidden_channels'],
            out_channels=out_channels,
            conv_class=cls,
            conv_kwargs=_conv_kw or None,
            **_model_kw,
        )

        _trainer = Trainer(
            model=_model,
            dataset_train=graph_dataset_train,
            dataset_val=graph_dataset_val,
            dataset_test=graph_dataset_test,
            batch_size=_params['batch_size'],
            model_kwargs={'lr': _params['lr'], 'num_epochs': _params['num_epochs']},
            reconcile=LOOP_PARAMS['reconcile'],
            top_level_model='xgb',
            lam_reg=0,
        )

        _result = _trainer.train(force_training=False, patience=_params['patience'])
        _pred, _target = _result[0], _result[1]

        torch.save(_pred, pred_path)
        with open(_params_path, 'w') as _pf:
            _json.dump(_current_params_key, _pf)
        trained_preds[conv_name] = _pred

        if target_national is None:
            target_national = _target.sum(dim=0).cpu()
            torch.save(target_national, _target_path)
            target_nodes = _target.cpu()
            torch.save(target_nodes, _target_nodes_path)

        _mape = 100 * MAPE(
            preds=_pred.sum(dim=0).cpu().detach(),
            targets=_target.sum(dim=0).cpu()
        ).item()
        print(f'  ✅ MAPE national = {_mape:.2f}%')

    except Exception as e:
        _msg = str(e).splitlines()[0] if str(e).strip() else type(e).__name__
        failed_loop[conv_name] = _msg
        print(f'  ❌ Failed: {_msg}')

    gc.collect()

print(f'\n✅ Successfully trained / cached: {len(trained_preds)}')
if failed_loop:
    print(f'❌ Failed during real-data training: {list(failed_loop.keys())}')
# Out:
# 🔄 Training AGNNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.43%
#
# 🔄 Training ARMAConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.31%
#
# 🔄 Training AntiSymmetricConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.47%
#
# 🔄 Training CGConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.38%
#
# 🔄 Training ChebConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.28%
#
# 🔄 Training ClusterGCNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.26%
#
# 🔄 Training DNAConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.24%
#
# 🔄 Training DirGNNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.33%
#
# 🔄 Training DynamicEdgeConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.22%
#
# 🔄 Training ECConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.31%
#
# 🔄 Training EGConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.23%
#
# 🔄 Training EdgeConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.34%
#
# 🔄 Training FAConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.26%
#
# 🔄 Training FastRGCNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.21%
#
# 🔄 Training FeaStConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.37%
#
# 🔄 Training FiLMConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.33%
#
# 🔄 Training GATConv... [optimized]
#    layers=5  hidden=179  lr=4.51e-04  batch=64  adj=eye  model_kw={'heads': 3}
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.34%
#
# 🔄 Training GATv2Conv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.27%
#
# 🔄 Training GCN2Conv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.32%
#
# 🔄 Training GCNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.27%
#
# 🔄 Training GENConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.25%
#
# 🔄 Training GINConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.22%
#
# 🔄 Training GINEConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.34%
#
# 🔄 Training GMMConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.34%
#
# 🔄 Training GatedGraphConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.32%
#
# 🔄 Training GeneralConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.35%
#
# 🔄 Training GraphConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.23%
#
# 🔄 Training GravNetConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.27%
#
# 🔄 Training LEConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.20%
#
# 🔄 Training LGConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.47%
#
# 🔄 Training MFConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.36%
#
# 🔄 Training MixHopConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.26%
#
# 🔄 Training NNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.31%
#
# 🔄 Training PANConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.37%
#
# 🔄 Training PDNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.25%
#
# 🔄 Training PNAConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.29%
#
# 🔄 Training RGATConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.27%
#
# 🔄 Training RGCNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.24%
#
# 🔄 Training ResGatedGraphConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.27%
#
# 🔄 Training SAGEConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.29%
#
# 🔄 Training SGConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.30%
#
# 🔄 Training SSGConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.28%
#
# 🔄 Training SignedConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.25%
#
# 🔄 Training SimpleConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.46%
#
# 🔄 Training SuperGATConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.38%
#
# 🔄 Training TAGConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.27%
#
# 🔄 Training TransformerConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        889.34       1.19       1.18
# val         1545.31       1.90       1.94
# test        1597.27       2.00       2.05
# Loading pretrained model.
#   ✅ MAPE national = 1.28%
#
# ✅ Successfully trained / cached: 47

# %%
import matplotlib.pyplot as plt
import numpy as np

# Compute MAPE per convolution and flag which already have optimized params
_scores = {}
for _name, _pred in trained_preds.items():
    _mape = 100 * MAPE(
        preds=_pred.sum(dim=0).cpu().detach(),
        targets=target_national.cpu()
    ).item()
    _scores[_name] = _mape

_names  = sorted(_scores, key=_scores.get)          # best (lowest MAPE) first
_values = [_scores[n] for n in _names]
_has_hpo = [os.path.exists(f'./results_optim_{n}/myGNN_best.json') for n in _names]

_colors = ['#2ecc71' if h else '#3498db' for h in _has_hpo]

fig, ax = plt.subplots(figsize=(9, max(4, 0.35 * len(_names))))
bars = ax.barh(_names, _values, color=_colors, edgecolor='white', linewidth=0.4)
ax.bar_label(bars, fmt='%.2f%%', padding=3, fontsize=8)
ax.set_xlabel('MAPE national (%)')
ax.set_title('Convolution benchmark - national MAPE (lower is better)')
ax.invert_yaxis()

from matplotlib.patches import Patch
ax.legend(handles=[
    Patch(color='#2ecc71', label='HPO done'),
    Patch(color='#3498db', label='Default params'),
], loc='lower right', fontsize=8)

plt.tight_layout()
plt.show()

# Print ranking for easy copy-paste into the HPO cell
print(f'\n{"Rank":<5} {"Convolution":<25} {"MAPE":>8}  HPO')
print('-' * 46)
for _rank, _name in enumerate(_names, 1):
    _marker = '✅' if _has_hpo[_rank - 1] else '❌'
    print(f'{_rank:<5} {_name:<25} {_scores[_name]:>7.2f}%  {_marker}')
# Out:
# Rank  Convolution                   MAPE  HPO
# ----------------------------------------------
# 1     LEConv                       1.20%  ❌
# 2     FastRGCNConv                 1.21%  ❌
# 3     DynamicEdgeConv              1.22%  ❌
# 4     GINConv                      1.22%  ❌
# 5     GraphConv                    1.23%  ❌
# 6     EGConv                       1.23%  ❌
# 7     DNAConv                      1.24%  ❌
# 8     RGCNConv                     1.24%  ❌
# 9     SignedConv                   1.25%  ❌
# 10    PDNConv                      1.25%  ❌
# 11    GENConv                      1.25%  ❌
# 12    ClusterGCNConv               1.26%  ❌
# 13    MixHopConv                   1.26%  ❌
# 14    FAConv                       1.26%  ❌
# 15    GCNConv                      1.27%  ❌
# 16    GATv2Conv                    1.27%  ❌
# 17    ResGatedGraphConv            1.27%  ❌
# 18    RGATConv                     1.27%  ❌
# 19    GravNetConv                  1.27%  ❌
# 20    TAGConv                      1.27%  ❌
# 21    ChebConv                     1.28%  ❌
# 22    TransformerConv              1.28%  ❌
# 23    SSGConv                      1.28%  ❌
# 24    SAGEConv                     1.29%  ❌
# 25    PNAConv                      1.29%  ❌
# 26    SGConv                       1.30%  ❌
# 27    ARMAConv                     1.31%  ❌
# 28    ECConv                       1.31%  ❌
# 29    NNConv                       1.31%  ❌
# 30    GatedGraphConv               1.32%  ❌
# 31    GCN2Conv                     1.32%  ❌
# 32    DirGNNConv                   1.33%  ❌
# 33    FiLMConv                     1.33%  ❌
# 34    GMMConv                      1.34%  ❌
# 35    GATConv                      1.34%  ✅
# 36    GINEConv                     1.34%  ❌
# 37    EdgeConv                     1.34%  ❌
# 38    GeneralConv                  1.35%  ❌
# 39    MFConv                       1.36%  ❌
# 40    PANConv                      1.37%  ❌
# 41    FeaStConv                    1.37%  ❌
# 42    CGConv                       1.38%  ❌
# 43    SuperGATConv                 1.38%  ❌
# 44    AGNNConv                     1.43%  ❌
# 45    SimpleConv                   1.46%  ❌
# 46    LGConv                       1.47%  ❌
# 47    AntiSymmetricConv            1.47%  ❌

# %% [markdown]
# ## Mixture of Experts with Opera
#
# The [opera-python](https://github.com/Dralliag/opera-python) library implements online sequential aggregation.
# Here we use the **MLpol** algorithm to optimally combine the national-level forecasts of all trained convolution models in a data-adaptive way, updating weights after each daily block.

# %%
import numpy as np
import pandas as pd
from opera import Mixture

assert target_national is not None, "Run the training loop above first."
assert trained_preds, "No predictions available."

T    = len(target_national)
step = out_channels                           # 48 - one prediction block = one day
y    = target_national.numpy().astype(float)  # ground-truth national total [T]

# --- build experts matrix (T × K), drop columns with NaN/Inf ---
experts_data = {}
for name, preds in trained_preds.items():
    national = preds.sum(dim=0).cpu().detach().numpy()[:T]
    experts_data[name] = national
experts_df = pd.DataFrame(experts_data)       # shape: T × K
bad_cols = experts_df.columns[~np.isfinite(experts_df.values).all(axis=0)].tolist()
if bad_cols:
    print(f"Dropping {len(bad_cols)} unstable expert(s): {bad_cols}")
    experts_df = experts_df.drop(columns=bad_cols)

print(f"Experts matrix: {experts_df.shape[1]} convolutions x {T} timesteps")
print(f"Block size: {step} (one day per update step)\n")

# --- Baselines ---
uniform_pred = experts_df.values.mean(axis=1)
print(f"Uniform average  -  RMSE: {RMSE(preds=uniform_pred, targets=y).item():>8.0f} MW   "
      f"MAPE: {100*MAPE(preds=uniform_pred, targets=y).item():.2f}%")

best_name = min(experts_df.columns,
    key=lambda n: MAPE(
        preds=experts_df[n].values.astype(float),
        targets=y
    ).item()
)
print(f"Best individual  -  {best_name:<25}  "
      f"RMSE: {RMSE(preds=experts_df[best_name].values.astype(float), targets=y).item():>8.0f} MW   "
      f"MAPE: {100*MAPE(preds=experts_df[best_name].values.astype(float), targets=y).item():.2f}%")

# --- Opera MLpol ---
n_experts = experts_df.shape[1]
predictions_opera = np.empty(T, dtype=float)

# Warm-up first block with uniform weights (no prior history)
w0 = np.ones(n_experts) / n_experts
predictions_opera[:step] = experts_df.iloc[:step].values @ w0

mixture = Mixture(
    y=y[:step],
    experts=experts_df.iloc[:step],
    model="MLpol",
    loss_type="mse",
)

for s in range(step, T, step):
    e = min(s + step, T)
    X_blk = experts_df.iloc[s:e]
    y_blk = y[s:e]
    pred_blk = mixture.predict(new_experts=X_blk)
    predictions_opera[s:e] = np.ravel(pred_blk)[:e - s]
    mixture.update(new_experts=X_blk, new_y=y_blk)

print(f"\nOpera MLpol     -  RMSE: {RMSE(preds=predictions_opera, targets=y).item():>8.0f} MW   "
      f"MAPE: {100*MAPE(preds=predictions_opera, targets=y).item():.2f}%")

# --- Final weights: mixture.weights is (T, K); take the last row ---
final_weights = pd.Series(
    mixture.weights[-1], index=experts_df.columns
).sort_values(ascending=False)
print("\nFinal expert weights (top 10):")
for name, w in final_weights.head(10).items():
    print(f"  {name:<30} {w:.4f}")
# Out:
# Experts matrix: 47 convolutions x 17376 timesteps
# Block size: 48 (one day per update step)
#
# Uniform average  -  RMSE:      870 MW   MAPE: 1.14%
# Best individual  -  LEConv                     RMSE:      889 MW   MAPE: 1.20%
# /var/folders/lc/jrt78rc56md09lxvkmwkgh7m0000gp/T/ipykernel_57520/1842712979.py:47: RuntimeWarning: divide by zero encountered in matmul
#   predictions_opera[:step] = experts_df.iloc[:step].values @ w0
# /var/folders/lc/jrt78rc56md09lxvkmwkgh7m0000gp/T/ipykernel_57520/1842712979.py:47: RuntimeWarning: overflow encountered in matmul
#   predictions_opera[:step] = experts_df.iloc[:step].values @ w0
# /var/folders/lc/jrt78rc56md09lxvkmwkgh7m0000gp/T/ipykernel_57520/1842712979.py:47: RuntimeWarning: invalid value encountered in matmul
#   predictions_opera[:step] = experts_df.iloc[:step].values @ w0
# Opera MLpol     -  RMSE:      860 MW   MAPE: 1.11%
#
# Final expert weights (top 10):
#   LEConv                         0.5894
#   GCNConv                        0.3101
#   GINConv                        0.0588
#   RGATConv                       0.0394
#   GENConv                        0.0023
#   AGNNConv                       0.0000
#   PDNConv                        0.0000
#   GravNetConv                    0.0000
#   LGConv                         0.0000
#   MFConv                         0.0000

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Reconstruct datetime index: 48 half-hours per day starting 2019-01-01
dates = pd.date_range(start='2019-01-01', periods=T, freq='30min')
months_idx = dates.to_period('M')
month_list = sorted(months_idx.unique())
month_short = [str(m)[-2:] for m in month_list]  # '01', '02', ...

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))

# --- Plot 1: Monthly MAPE ---
opera_mapes, uniform_mapes, best_mapes = [], [], []
for month in month_list:
    mask = (months_idx == month)
    y_m  = y[mask]
    opera_mapes.append(100 * float(MAPE(preds=predictions_opera[mask], targets=y_m)))
    uniform_mapes.append(100 * float(MAPE(preds=uniform_pred[mask], targets=y_m)))
    best_mapes.append(100 * float(MAPE(preds=experts_df[best_name].values[mask].astype(float), targets=y_m)))

x = np.arange(len(month_list))
w = 0.25
ax1.bar(x - w, opera_mapes,   w, label='Opera MLpol', color='steelblue')
ax1.bar(x,     uniform_mapes, w, label='Uniform avg',  color='silver')
ax1.bar(x + w, best_mapes,    w, label=best_name,      color='salmon')
ax1.set_xticks(x)
ax1.set_xticklabels(month_short)
ax1.set_xlabel('Month (2019)')
ax1.set_ylabel('MAPE (%)')
ax1.set_title('Monthly national MAPE')
ax1.legend()

# --- Plot 2: Top expert weights per month ---
N_top = 8
top_experts = final_weights.head(N_top).index.tolist()

# mixture.weights is (T, K); take weight vector at last timestep of each month
weights_mat = np.array(mixture.weights)   # (T, K)
monthly_w = []
for month in month_list:
    last_t = int(np.where((months_idx == month))[0][-1])
    monthly_w.append(weights_mat[last_t])
monthly_w = np.array(monthly_w)           # (n_months, K)
weights_monthly_df = pd.DataFrame(monthly_w, columns=experts_df.columns, index=month_short)

for expert in top_experts:
    ax2.plot(month_short, weights_monthly_df[expert], marker='o', linewidth=1.8, label=expert)

ax2.set_xlabel('Month (2019)')
ax2.set_ylabel('Expert weight (MLpol)')
ax2.set_title(f'Top {N_top} expert weights over time')
ax2.legend(fontsize=8, bbox_to_anchor=(1.02, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Opera Bottom-Up Aggregation
#
# Instead of aggregating at the national level, we can run **MLpol independently per node** and then sum.
# Each regional Opera mixture learns node-specific expert weights; the national aggregate is the sum of all reconciled bottom-level predictions.
# This is strictly more expressive than top-level aggregation because different regions can favour different experts.

# %%
import numpy as np
import pandas as pd
from opera import Mixture

assert target_nodes is not None, "Run the training loop above first (target_nodes must be saved)."
assert trained_preds, "No predictions available."

T    = len(target_national)
step = out_channels                               # 48 — one prediction block per day
y_global = target_national.numpy().astype(float)

# --- drop unstable experts (same as top-level cell) ---
_valid_names = [n for n in trained_preds if n not in (bad_cols if 'bad_cols' in dir() else [])]
N_nodes = target_nodes.shape[0]

print(f"Running per-node Opera MLpol ({N_nodes} nodes x {len(_valid_names)} experts)...")

node_opera_preds = []
for node_idx in range(N_nodes):
    y_node = target_nodes[node_idx].numpy().astype(float)

    node_experts = {name: trained_preds[name][node_idx].cpu().detach().numpy()[:T]
                    for name in _valid_names}
    node_df = pd.DataFrame(node_experts)

    # Drop any NaN/Inf columns for this node
    bad_node = node_df.columns[~np.isfinite(node_df.values).all(axis=0)].tolist()
    if bad_node:
        node_df = node_df.drop(columns=bad_node)
    n_exp = node_df.shape[1]
    w0 = np.ones(n_exp) / n_exp

    node_pred = np.empty(T, dtype=float)
    node_pred[:step] = node_df.iloc[:step].values @ w0

    mix_node = Mixture(
        y=y_node[:step],
        experts=node_df.iloc[:step],
        model="MLpol",
        loss_type="mse",
    )
    for s in range(step, T, step):
        e = min(s + step, T)
        X_blk = node_df.iloc[s:e]
        pred_blk = mix_node.predict(new_experts=X_blk)
        node_pred[s:e] = np.ravel(pred_blk)[:e - s]
        mix_node.update(new_experts=X_blk, new_y=y_node[s:e])

    node_opera_preds.append(node_pred)

node_opera_preds = np.stack(node_opera_preds, axis=0)   # [N, T]
predictions_opera_bu = node_opera_preds.sum(axis=0)      # national aggregate

print(f"\n{'Method':<30} {'RMSE':>10} {'MAPE':>8}")
print("-" * 52)
for label, pred in [
    ("Opera MLpol (top-level)", predictions_opera),
    ("Opera MLpol (bottom-up)", predictions_opera_bu),
    ("Uniform average",         uniform_pred),
    (f"Best individual ({best_name})", experts_df[best_name].values.astype(float)),
]:
    rmse = RMSE(preds=pred, targets=y_global).item()
    mape = 100 * MAPE(preds=pred, targets=y_global).item()
    print(f"{label:<30} {rmse:>10.0f} MW  {mape:>6.2f}%")
# Out:
# Running per-node Opera MLpol (12 nodes x 47 experts)...
# /var/folders/lc/jrt78rc56md09lxvkmwkgh7m0000gp/T/ipykernel_57520/1964913297.py:34: RuntimeWarning: divide by zero encountered in matmul
#   node_pred[:step] = node_df.iloc[:step].values @ w0
# /var/folders/lc/jrt78rc56md09lxvkmwkgh7m0000gp/T/ipykernel_57520/1964913297.py:34: RuntimeWarning: overflow encountered in matmul
#   node_pred[:step] = node_df.iloc[:step].values @ w0
# /var/folders/lc/jrt78rc56md09lxvkmwkgh7m0000gp/T/ipykernel_57520/1964913297.py:34: RuntimeWarning: invalid value encountered in matmul
#   node_pred[:step] = node_df.iloc[:step].values @ w0
# Method                               RMSE     MAPE
# ----------------------------------------------------
# Opera MLpol (top-level)               860 MW    1.11%
# Opera MLpol (bottom-up)               849 MW    1.10%
# Uniform average                       870 MW    1.14%
# Best individual (LEConv)              889 MW    1.20%

# %%
# Per-instant attention matrices exist because each graph in the batch is one time step
# (30 min). The attention mechanism reweights the 12x12 region graph differently per
# instant based on current load/temperature features - G=17376 matrices for the test year.
#
# The Trainer's save mechanism relies on myGNN handling save=True/save_path kwargs, which
# it currently does not. We collect attention manually from ConvAdapter.last_attention.

import gc, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from torch_geometric.loader import DataLoader as PyGDataLoader

attn_conv = GATv2Conv
adj_matrix = 'dtw'

# --- 1. Load GATv2Conv from checkpoint ---
seed_everything(42)
gc.collect()

_gat_model = myGNN(
    in_channels=graph_dataset_train.num_node_features,
    num_layers=LOOP_PARAMS['num_layers'],
    hidden_channels=LOOP_PARAMS['hidden_channels'],
    out_channels=out_channels,
    conv_class=attn_conv,
)

_ckpt_dir = f"./checkpoints/{attn_conv.__name__}_{adj_matrix}/batch{LOOP_PARAMS['batch_size']}_hidden{LOOP_PARAMS['hidden_channels']}_layers{LOOP_PARAMS['num_layers']}_epochs{LOOP_PARAMS['num_epochs']}"
_ckpt_file = sorted(os.listdir(_ckpt_dir))[-1]
_gat_model.load_state_dict(torch.load(os.path.join(_ckpt_dir, _ckpt_file), weights_only=False))
_gat_model.eval()
print(f"Loaded {_ckpt_file}")

# --- 2. Run inference on test set and save per-batch attention dumps ---
_save_dir = f'./attention_matrix/{attn_conv.__name__}_{adj_matrix}/test_batch{LOOP_PARAMS["batch_size"]}_hidden{LOOP_PARAMS["hidden_channels"]}_layers{LOOP_PARAMS["num_layers"]}_epochs{LOOP_PARAMS["num_epochs"]}_heads1'
os.makedirs(_save_dir, exist_ok=True)
for f in os.listdir(_save_dir):           # clear stale empty files
    os.remove(os.path.join(_save_dir, f))

_test_loader = PyGDataLoader(graph_dataset_test, batch_size=LOOP_PARAMS['batch_size'],
                              shuffle=False, drop_last=False)

with torch.no_grad():
    for i, batch in enumerate(_test_loader):
        for attr in ['x', 'y_scaled', 'y', 'edge_weight', 'mask_y']:
            if getattr(batch, attr, None) is not None:
                setattr(batch, attr, getattr(batch, attr).float())

        _gat_model(batch.x, batch.edge_index,
                   edge_weight=getattr(batch, 'edge_weight', None),
                   return_attention=True)

        # Collect raw [E_total, H] attention from each layer's ConvAdapter
        attn_raw = []
        for layer in _gat_model.layers:
            ca = layer.conv
            if ca.last_attention is not None:
                _, aw = ca.last_attention   # aw: [E_total, H]
                attn_raw.append(aw.detach().cpu())

        if attn_raw:
            B = int(batch.num_graphs)
            E_total = batch.edge_index.shape[1]
            E_graph = E_total // B
            # First graph starts at node 0 - no offset needed for its edges
            ei_single = batch.edge_index[:, :E_graph].detach().cpu()
            torch.save({'attention_weights': attn_raw,
                        'edge_idx': ei_single,
                        'num_graphs': B},
                       f'{_save_dir}/num_batch{i}.pt')

n_saved = len(os.listdir(_save_dir))
print(f"Saved {n_saved} attention dumps")

# --- 3. Load and assemble ---
all_attentions, edge_index_attn = load_attention_batches(_save_dir)
L, H, G, E = all_attentions.shape
print(f"Attention tensor: L={L} layers  H={H} heads  G={G} instants  E={E} edges")

# --- 4. Month label for each instant ---
dates_attn  = pd.date_range(start='2019-01-01', periods=G, freq='D')
month_labels = dates_attn.month.values
month_names  = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# --- 5. Monthly mean attention - per-month colour scale ---
# Global vmax (January dominates ~0.12) maps all other months near white.
# Per-month normalisation reveals spatial patterns; subtitle shows absolute max.
src, tgt = edge_index_attn[0].long(), edge_index_attn[1].long()
N_nodes  = int(max(src.max(), tgt.max()).item()) + 1
attn_lh  = all_attentions.mean(dim=(0, 1))   # [G, E]

fig, axes = plt.subplots(2, 6, figsize=(18, 6))
axes = axes.ravel()
month_maxes = []
for m_idx in range(12):
    mask   = month_labels == (m_idx + 1)
    attn_m = attn_lh[mask].mean(dim=0)        # [E]
    mat    = torch.zeros(N_nodes, N_nodes)
    mat[src, tgt] = attn_m.float()
    m_max  = float(mat.max())
    month_maxes.append(m_max)
    sns.heatmap(mat.numpy(), ax=axes[m_idx], cmap='rocket_r',
                cbar=True, vmin=0, vmax=m_max if m_max > 0 else 1,
                xticklabels=False, yticklabels=False,
                cbar_kws={'shrink': 0.7})
    axes[m_idx].set_title(f'{month_names[m_idx]}\nmax={m_max:.3f}', fontsize=9)

fig.suptitle(f'{attn_conv.__name__} - Mean attention matrix per month (2019)\n'
             'Per-month colour scale  |  darker = higher attention', fontsize=12)
plt.tight_layout()
plt.show()

# Absolute attention strength by month
global_vmax = float(np.nanmax(month_maxes)) if any(np.isfinite(month_maxes)) else 1.0
print("\nAbsolute max attention per month (higher = stronger inter-region coupling):")
for mn, mx in zip(month_names, month_maxes):
    bar = '█' * int(mx / global_vmax * 30) if np.isfinite(mx) and global_vmax > 0 else '?'
    print(f'  {mn:>3}  {mx:.4f}  {bar}')

# --- 6. Animated evolution - shared scale so magnitudes are comparable across frames ---
global_vmax = max(month_maxes)
html_anim = animate_grouped_attention(
    all_attentions=all_attentions,
    edge_index=edge_index_attn,
    group_variable=month_labels,
    group_name='Month',
    interval=900,
    mode='mean',
    vmin=0, vmax=global_vmax,
    gif_path=f'./attention_matrix/{attn_conv.__name__}_{adj_matrix}/attention_monthly_mean.gif',
)
html_anim
# Out:
# Loaded epoch198.params
# Saved 12 attention dumps
# Attention tensor: L=2 layers  H=1 heads  G=362 instants  E=142 edges
# Absolute max attention per month (higher = stronger inter-region coupling):
#   Jan  0.0892  █████████████████████████████
#   Feb  0.0897  █████████████████████████████
#   Mar  0.0899  █████████████████████████████
#   Apr  0.0882  █████████████████████████████
#   May  0.0903  █████████████████████████████
#   Jun  0.0877  ████████████████████████████
#   Jul  0.0868  ████████████████████████████
#   Aug  0.0878  █████████████████████████████
#   Sep  0.0898  █████████████████████████████
#   Oct  0.0907  ██████████████████████████████
#   Nov  0.0883  █████████████████████████████
#   Dec  0.0891  █████████████████████████████
# GIF saved at: /Users/eloicampagne/Desktop/EDF/GraphToolbox/examples/load/attention_matrix/GATv2Conv_dtw/attention_monthly_mean.gif
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img196aa5ae3c25400c8d4044dc4cdd9012">
#   <div class="anim-controls">
#     <input id="_anim_slider196aa5ae3c25400c8d4044dc4cdd9012" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim196aa5ae3c25400c8d4044dc4cdd9012.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim196aa5ae3c25400c8d4044dc4cdd9012.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select196aa5ae3c25400c8d4044dc4cdd9012"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_196aa5ae3c25400c8d4044dc4cdd9012"
#              >
#       <label for="_anim_radio1_196aa5ae3c25400c8d4044dc4cdd9012">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_196aa5ae3c25400c8d4044dc4cdd9012"
#              checked>
#       <label for="_anim_radio2_196aa5ae3c25400c8d4044dc4cdd9012">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_196aa5ae3c25400c8d4044dc4cdd9012"
#              >
#       <label for="_anim_radio3_196aa5ae3c25400c8d4044dc4cdd9012">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img196aa5ae3c25400c8d4044dc4cdd9012";
#     var slider_id = "_anim_slider196aa5ae3c25400c8d4044dc4cdd9012";
#     var loop_select_id = "_anim_loop_select196aa5ae3c25400c8d4044dc4cdd9012";
#     var frames = new Array(12);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8fJSN1AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABnpUlEQ
