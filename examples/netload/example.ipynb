# %% [markdown]
# # GraphToolbox - NetLoad Example
#
# This notebook forecasts the **net-load** (`NetLoad = Load - Wind_power - Solar_power`)
# over the French regional graph, and is brought in line with the more complete
# *Load Example*. Relative to the original net-load notebook it adds:
#
# 1. **Correct metrics.** MAPE is unsafe for solar/wind (zero at night, frequent
#    lulls) and for per-region net-load (sign changes). RMSE / nRMSE / MAE / sMAPE
#    are used instead where appropriate.
# 2. **Physical / non-linear features** for each component (heating-cooling degrees,
#    `wind^3`, cloud clearness, seasonal solar geometry), in the spirit of the load
#    notebook's `computed_features`.
# 3. A clean **direct-vs-decomposed comparison** and a **reconciliation** section
#    (online MLpol over the two approaches), instead of committing to one a priori.
# 4. The load notebook's **analysis machinery** adapted to net-load: an
#    all-convolutions benchmark, Opera MLpol mixture-of-experts, expert pruning,
#    bottom-up aggregation, a per-region error map, and error diagnostics.

# %% [markdown]
# This notebook was succesfully tested with Python 3.11.9.

# %% [markdown]
# ## Importing libraries

# %% [markdown]
# Importing all libraries should take a minute or two.

# %%
# General libraries
import gc
import os
import json as _json
from scipy.stats import norm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch_geometric.nn.conv import *
from torch_geometric.nn.models import *
from torch_geometric import seed_everything

# GraphToolbox
from graphtoolbox.data.dataset import *
from graphtoolbox.models.gnn import *
from graphtoolbox.optim.optimizer import *
from graphtoolbox.training.trainer import Trainer
from graphtoolbox.utils.attention import *
from graphtoolbox.utils.helper_functions import *
from graphtoolbox.utils.visualizations import *

# Autoreload
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Metrics: why not MAPE here
#
# `MAPE = mean(|pred - true| / |true|)` explodes as `|true| -> 0` and is undefined
# across a sign change. That is exactly the renewable regime: **solar** is identically
# zero every night (the original notebook reported a solar "MAPE" of $\sim 8.1e8 \%$),
# **wind** is frequently near zero ($\sim 45 \%$ MAPE, dominated by lulls), and **net-load**
# itself can approach zero / go negative in high-penetration regions. The rule used
# below: MAPE only on strictly-positive series (load, national net-load); otherwise
# RMSE / nRMSE / MAE / sMAPE.

# %%
# ── Evaluation metrics ────────────────────────────────────────────────────────
def _to_np(x):
    if isinstance(x, torch.Tensor):
        return x.detach().cpu().numpy().astype(float)
    return np.asarray(x, dtype=float)

def rmse_np(pred, true):
    p, t = _to_np(pred), _to_np(true)
    return float(np.sqrt(np.mean((p - t) ** 2)))

def mae_np(pred, true):
    p, t = _to_np(pred), _to_np(true)
    return float(np.mean(np.abs(p - t)))

def nrmse_np(pred, true, denom=None):
    """RMSE normalised by `denom` (default: mean of |true|), in %."""
    p, t = _to_np(pred), _to_np(true)
    d = np.mean(np.abs(t)) if denom is None else float(denom)
    return 100.0 * np.sqrt(np.mean((p - t) ** 2)) / max(d, 1e-8)

def smape_np(pred, true):
    """Symmetric MAPE (%), bounded in [0, 200]; safe near zero."""
    p, t = _to_np(pred), _to_np(true)
    return 100.0 * np.mean(2 * np.abs(p - t) / (np.abs(p) + np.abs(t) + 1e-8))

def mape_np(pred, true, eps=1e-6):
    """Plain MAPE (%). Use ONLY on strictly-positive series (e.g. load)."""
    p, t = _to_np(pred), _to_np(true)
    return 100.0 * np.mean(np.abs(p - t) / np.clip(np.abs(t), eps, None))

def report(name, pred, true, capacity=None):
    """One-line metric summary appropriate for a possibly-zero-crossing target."""
    line = (f"{name:<28} RMSE={rmse_np(pred, true):8.0f}  "
            f"MAE={mae_np(pred, true):8.0f}  "
            f"nRMSE={nrmse_np(pred, true):6.2f}%  "
            f"sMAPE={smape_np(pred, true):6.2f}%")
    if capacity is not None:
        line += f"  nRMSE/cap={nrmse_np(pred, true, denom=capacity):6.2f}%"
    print(line)

# %% [markdown]
# ## Feature engineering
#
# Physical / non-linear features for the three signals that make up net-load. They
# are computed once on the raw dataframe and *selected per model* via `features_base`.
# `day_length` / `solar_pot` are deterministic seasonal solar-geometry terms (daily
# granularity, the intra-day shape lives in the 48-dim output); using a single
# representative French latitude here, per-region latitude (via `df_pos`) is a refinement.

# %%
# ── Feature-engineering helpers ───────────────────────────────────────────────
FRANCE_LAT_DEG = 46.6

def _day_of_year(df):
    return pd.to_datetime(df['date']).dt.dayofyear.astype(float)

def solar_declination(df):                      # Cooper's approximation (deg)
    return 23.45 * np.sin(np.deg2rad(360.0 * (284.0 + _day_of_year(df)) / 365.0))

def day_length_hours(df, lat_deg=FRANCE_LAT_DEG):
    decl, lat = np.deg2rad(solar_declination(df)), np.deg2rad(lat_deg)
    cos_ws = np.clip(-np.tan(lat) * np.tan(decl), -1.0, 1.0)
    return (24.0 / np.pi) * np.arccos(cos_ws)

def extraterrestrial_daily(df, lat_deg=FRANCE_LAT_DEG):
    """Top-of-atmosphere daily irradiation proxy (unitless solar potential)."""
    decl, lat = np.deg2rad(solar_declination(df)), np.deg2rad(lat_deg)
    ws = np.arccos(np.clip(-np.tan(lat) * np.tan(decl), -1.0, 1.0))
    dr = 1.0 + 0.033 * np.cos(np.deg2rad(360.0 * _day_of_year(df) / 365.0))
    return dr * (ws * np.sin(lat) * np.sin(decl) + np.cos(lat) * np.cos(decl) * np.sin(ws))

# Shared computed features (selected per-model via features_base).
COMPUTED_FEATURES = {
    # Load: non-linear temperature response
    'heat_deg': lambda df: (15.0 - df['temperature']).clip(lower=0),
    'cool_deg': lambda df: (df['temperature'] - 15.0).clip(lower=0),
    'temp_sq':  lambda df: df['temperature'] ** 2,
    # Wind: power ~ wind_speed^3 (up to rated)
    'wind_cubed':     lambda df: df['wind'].clip(lower=0) ** 3,
    'wind_cap_cubed': lambda df: df['wind_by_wind_power_weights'].clip(lower=0) ** 3,
    # Solar: clearness = 1 - cloud cover, modulating the clear-sky envelope
    'clearness':    lambda df: (1.0 - df['nebulosity']).clip(lower=0, upper=1),
    'clearness_sq': lambda df: ((1.0 - df['nebulosity']).clip(lower=0, upper=1)) ** 2,
    # Solar seasonal geometry (deterministic, daily)
    'day_length': lambda df: day_length_hours(df),
    'solar_pot':  lambda df: extraterrestrial_daily(df),
}
ENG_LOAD  = ['heat_deg', 'cool_deg', 'temp_sq']
ENG_WIND  = ['wind_cubed', 'wind_cap_cubed']
ENG_SOLAR = ['clearness', 'clearness_sq', 'day_length', 'solar_pot']

# %% [markdown]
# ## CUDA or not CUDA ?

# %%
print('CUDA'*(torch.cuda.is_available())+(1-torch.cuda.is_available())*'not CUDA')
# Out:
# not CUDA

# %% [markdown]
# # Part 1 :  Direct net-load model (one GNN)
#
# A single GNN forecasts `NetLoad` directly. Because this model has to represent load,
# wind and solar at once, it is given the **union** of all component features plus every
# engineered term, so the comparison against the three specialised models in Part 2 is fair.

# %%
data_kwargs = {
    'node_var': 'Region',
    'features_to_lag': {'NetLoad': (1, 48), 'temperature': (-47, -1)},
    'dummies': ['tod', 'day_type_week'],
    'day_inf_train': '2014-01-01',
    'day_sup_train': '2018-01-01',
    'day_inf_val':   '2018-01-01',
    'day_sup_val':   '2018-12-31',
    'day_inf_test':  '2019-01-01',
    'day_sup_test':  '2019-12-31',
    'computed_features': COMPUTED_FEATURES,  
}

features_load  = ['temperature', 'temperature_lisse_990', 'temperature_lisse_950', 'wind', 'nebulosity',
                  'toy', 'year', 'month', 'day_type_jf', 'day_type_week', 'period_holiday', 'period_hour_changed',
                  'period_holiday_zone_a', 'period_holiday_zone_b', 'period_holiday_zone_c', 'period_christmas', 'period_summer']
features_wind  = ['wind', 'wind_by_wind_power_weights', 'toy', 'year', 'month']
features_solar = ['nebulosity', 'nebulosity_by_solar_power_weights', 'toy', 'year', 'month']

# Direct net-load sees everything (fair comparison vs the 3 specialists):
features = sorted(set(features_load) | set(features_wind) | set(features_solar)
                  | set(ENG_LOAD) | set(ENG_WIND) | set(ENG_SOLAR))

dataset_kwargs = {
    'batch_size': 32,
    'adj_matrix': 'dtw',
    'features_base': features + [f'NetLoad_l{t}' for t in range(1, 48 + 1)]
                              + [f'temperature_l{t}' for t in range(-47, -1 + 1)],
    'target_base': 'NetLoad',
}

out_channels = 48
data = DataClass(path_train='./train.csv', path_test='./test.csv',
                 data_kwargs=data_kwargs, folder_config='.')

graph_dataset_train = GraphDataset(data=data, period='train',
                                   graph_folder='../graph_representations',
                                   dataset_kwargs=dataset_kwargs, out_channels=out_channels)
graph_dataset_val = GraphDataset(data=data, period='val',
                                 scalers_feat=graph_dataset_train.scalers_feat,
                                 scalers_target=graph_dataset_train.scalers_target,
                                 graph_folder='../graph_representations',
                                 dataset_kwargs=dataset_kwargs, out_channels=out_channels)
graph_dataset_test = GraphDataset(data=data, period='test',
                                  scalers_feat=graph_dataset_train.scalers_feat,
                                  scalers_target=graph_dataset_train.scalers_target,
                                  graph_folder='../graph_representations',
                                  dataset_kwargs=dataset_kwargs, out_channels=out_channels)

# %% [markdown]
# ## Training the direct model
#
# If a pre-trained model with the same parameters exists, the trainer loads it
# automatically (use `force_training=True` to retrain).

# %%
gc.collect()
torch.cuda.empty_cache()
seed_everything(seed=42)

conv_class = LEConv
conv_kwargs = {}
params = {'num_layers': 2, 'hidden_channels': 256, 'lr': 1e-3, 'batch_size': 16, 'adj_matrix': 'space', 'lam_reg': 0}

graph_dataset_train._set_adj_matrix(adj_matrix=params['adj_matrix'])
graph_dataset_val._set_adj_matrix(adj_matrix=params['adj_matrix'])
graph_dataset_test._set_adj_matrix(adj_matrix=params['adj_matrix'])

model = myGNN(
    in_channels=graph_dataset_train.num_node_features,
    num_layers=params["num_layers"],
    hidden_channels=params["hidden_channels"],
    out_channels=out_channels,
    conv_class=conv_class,
    conv_kwargs=conv_kwargs
)
trainer = Trainer(
    model=model,
    dataset_train=graph_dataset_train,
    dataset_val=graph_dataset_val,
    dataset_test=graph_dataset_test,
    batch_size=params["batch_size"],
    model_kwargs={'lr': params["lr"], 'num_epochs': 300},
    reconcile=True,
    top_level_model='xgb',
    lam_reg=0
)

pred_model_test, target_test, edge_index, attention_weights = trainer.train(
    plot_loss=True, force_training=False, save=True, patience=75
)
trainer.evaluate()

# National net-load is positive at country scale, so MAPE is acceptable here,
# but RMSE / nRMSE are the headline going forward.
report('Direct net-load (national)', pred_model_test.sum(0), target_test.sum(0))
# Out:
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train       1191.77       1.80       1.77
# val         2008.44       2.97       2.95
# test        2489.91       4.06       3.93
# Loading pretrained model.
# MAPE on test set: 3.3907 %
# RMSE on test set: 2051.2612 MW
# Direct net-load (national)   RMSE=    2051  MAE=    1566  nRMSE=  4.24%  sMAPE=  3.36%

# %% [markdown]
# To visualize your predictions for each node, you can use the `plot_nodes()` method.

# %%
plot_nodes(true=target_test, pred=pred_model_test, graph_dataset=graph_dataset_test)

# %% [markdown]
# # Part 2 : Decomposition: one GNN per component (load / wind / solar)
#
# `NetLoad = Load - Wind_power - Solar_power`. Each component has very different
# dynamics, so each model gets its **own features** (load: temperature non-linearities;
# wind: `wind^3`; solar: clearness + seasonal geometry) and should get its **own
# hyperparameters** (tune them with the Optuna scaffold in Part 4 rather than copying
# one set across all three, as the original notebook did).

# %%
data_kwargs = {
    'node_var': 'Region',
    'features_to_lag': {'Load': (1, 48), 'Wind_power': (1, 48), 'Solar_power': (1, 48), 'temperature': (-47, -1)},
    'dummies': ['tod', 'day_type_week'],
    'day_inf_train': '2014-01-01',
    'day_sup_train': '2018-01-01',
    'day_inf_val':   '2018-01-01',
    'day_sup_val':   '2018-12-31',
    'day_inf_test':  '2019-01-01',
    'day_sup_test':  '2019-12-31',
    'computed_features': COMPUTED_FEATURES,
}

features_load  = ['temperature', 'temperature_lisse_990', 'temperature_lisse_950', 'wind', 'nebulosity',
                  'toy', 'year', 'month', 'day_type_jf', 'day_type_week', 'period_holiday', 'period_hour_changed',
                  'period_holiday_zone_a', 'period_holiday_zone_b', 'period_holiday_zone_c', 'period_christmas', 'period_summer'] + ENG_LOAD
features_wind  = ['wind', 'wind_by_wind_power_weights', 'toy', 'year', 'month'] + ENG_WIND
features_solar = ['nebulosity', 'nebulosity_by_solar_power_weights', 'toy', 'year', 'month'] + ENG_SOLAR

dataset_kwargs_load = {
    'batch_size': 32, 'adj_matrix': 'dtw',
    'features_base': features_load + [f'Load_l{t}' for t in range(1, 48 + 1)] + [f'temperature_l{t}' for t in range(-47, -1 + 1)],
    'target_base': 'Load',
}
dataset_kwargs_wind = {
    'batch_size': 32, 'adj_matrix': 'dtw',
    'features_base': features_wind + [f'Wind_power_l{t}' for t in range(1, 48 + 1)] + [f'temperature_l{t}' for t in range(-47, -1 + 1)],
    'target_base': 'Wind_power',
}
dataset_kwargs_solar = {
    'batch_size': 32, 'adj_matrix': 'dtw',
    'features_base': features_solar + [f'Solar_power_l{t}' for t in range(1, 48 + 1)] + [f'temperature_l{t}' for t in range(-47, -1 + 1)],
    'target_base': 'Solar_power',
}

out_channels = 48
data = DataClass(path_train='./train.csv', path_test='./test.csv',
                 data_kwargs=data_kwargs, folder_config='.')

def _make_datasets(dk):
    tr = GraphDataset(data=data, period='train', graph_folder='../graph_representations',
                      dataset_kwargs=dk, out_channels=out_channels)
    va = GraphDataset(data=data, period='val', scalers_feat=tr.scalers_feat,
                      scalers_target=tr.scalers_target, graph_folder='../graph_representations',
                      dataset_kwargs=dk, out_channels=out_channels)
    te = GraphDataset(data=data, period='test', scalers_feat=tr.scalers_feat,
                      scalers_target=tr.scalers_target, graph_folder='../graph_representations',
                      dataset_kwargs=dk, out_channels=out_channels)
    return tr, va, te

graph_dataset_train_load,  graph_dataset_val_load,  graph_dataset_test_load  = _make_datasets(dataset_kwargs_load)
graph_dataset_train_wind,  graph_dataset_val_wind,  graph_dataset_test_wind  = _make_datasets(dataset_kwargs_wind)
graph_dataset_train_solar, graph_dataset_val_solar, graph_dataset_test_solar = _make_datasets(dataset_kwargs_solar)

# %%
# Per-component architecture / hyperparameters.
# These MUST be tuned independently (Part 4), wind and solar are not load.
# The values below are only sensible starting points, kept distinct on purpose.

### LOAD
conv_class_load = LEConv
conv_kwargs_load = {}
params_load = {'num_layers': 2, 'hidden_channels': 128, 'lr': 1e-3, 'batch_size': 32, 'adj_matrix': 'space', 'lam_reg': 0}

### WIND  (stochastic, weak diurnal pattern start simpler/deeper)
conv_class_wind = LEConv
conv_kwargs_wind = {}
params_wind = {'num_layers': 2, 'hidden_channels': 128, 'lr': 1e-3, 'batch_size': 32, 'adj_matrix': 'space', 'lam_reg': 0}

### SOLAR (strong deterministic envelope + cloud noise)
conv_class_solar = LEConv
conv_kwargs_solar = {}
params_solar = {'num_layers': 2, 'hidden_channels': 128, 'lr': 1e-3, 'batch_size': 32, 'adj_matrix': 'space', 'lam_reg': 0}

for _ds in [graph_dataset_train_load, graph_dataset_val_load, graph_dataset_test_load]:
    _ds._set_adj_matrix(adj_matrix=params_load['adj_matrix'])
for _ds in [graph_dataset_train_wind, graph_dataset_val_wind, graph_dataset_test_wind]:
    _ds._set_adj_matrix(adj_matrix=params_wind['adj_matrix'])
for _ds in [graph_dataset_train_solar, graph_dataset_val_solar, graph_dataset_test_solar]:
    _ds._set_adj_matrix(adj_matrix=params_solar['adj_matrix'])

# %%
### LOAD : load is strongly positive, so MAPE is meaningful for this component.
seed_everything(seed=42); gc.collect()
model_load = myGNN(
    in_channels=graph_dataset_train_load.num_node_features,
    num_layers=params_load["num_layers"], hidden_channels=params_load["hidden_channels"],
    out_channels=out_channels, conv_class=conv_class_load, conv_kwargs=conv_kwargs_load,
)
trainer_load = Trainer(
    model=model_load, dataset_train=graph_dataset_train_load,
    dataset_val=graph_dataset_val_load, dataset_test=graph_dataset_test_load,
    batch_size=params_load["batch_size"], return_attention=False,
    reconcile=True, top_level_model='xgb',
    model_kwargs={'lr': params_load["lr"], 'num_epochs': 300}, lam_reg=0,
)
pred_model_test_load, target_test_load, edge_index, attention_weights_load = trainer_load.train(
    plot_loss=True, force_training=False, save=True, patience=75
)
trainer_load.evaluate()
print(f"Load (national) MAPE = {mape_np(pred_model_test_load.sum(0), target_test_load.sum(0)):.2f}%")
report('Load (national)', pred_model_test_load.sum(0), target_test_load.sum(0))
# Out:
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        933.53       1.24       1.24
# val         1519.94       1.87       1.92
# test        1550.78       1.95       1.99
# Training model...
# 100%|██████████| 300/300 [02:20<00:00,  2.13it/s]
# MAPE on test set: 1.1275 %
# RMSE on test set: 851.8525 MW
# Load (national) MAPE = 1.13%
# Load (national)              RMSE=     852  MAE=     610  nRMSE=  1.59%  sMAPE=  1.13%

# %%
### WIND : near-zero often; DO NOT use MAPE. RMSE / nRMSE / MAE only.
seed_everything(seed=42); gc.collect()
model_wind = myGNN(
    in_channels=graph_dataset_train_wind.num_node_features,
    num_layers=params_wind["num_layers"], hidden_channels=params_wind["hidden_channels"],
    out_channels=out_channels, conv_class=conv_class_wind, conv_kwargs=conv_kwargs_wind,
)
trainer_wind = Trainer(
    model=model_wind, dataset_train=graph_dataset_train_wind,
    dataset_val=graph_dataset_val_wind, dataset_test=graph_dataset_test_wind,
    batch_size=params_wind["batch_size"], return_attention=False,
    reconcile=True, top_level_model='xgb',
    model_kwargs={'lr': params_wind["lr"], 'num_epochs': 300}, lam_reg=0,
)
pred_model_test_wind, target_test_wind, edge_index, attention_weights_wind = trainer_wind.train(
    plot_loss=True, force_training=False, save=True, patience=75   # cache like load
)
report('Wind (national)', pred_model_test_wind.sum(0), target_test_wind.sum(0))
# Out:
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        612.42      29.89      19.06
# val         1105.06      35.44      25.09
# test        1397.89      36.71      26.35
# Training model...
#  39%|███▉      | 118/300 [00:55<01:25,  2.12it/s]
# Early stopping at epoch 118
# Wind (national)              RMSE=    1629  MAE=    1167  nRMSE= 42.12%  sMAPE= 34.90%

# %%
### SOLAR : exactly zero every night; MAPE is undefined. RMSE / nRMSE / MAE only.
seed_everything(seed=42); gc.collect()
model_solar = myGNN(
    in_channels=graph_dataset_train_solar.num_node_features,
    num_layers=params_solar["num_layers"], hidden_channels=params_solar["hidden_channels"],
    out_channels=out_channels, conv_class=conv_class_solar, conv_kwargs=conv_kwargs_solar,
)
trainer_solar = Trainer(
    model=model_solar, dataset_train=graph_dataset_train_solar,
    dataset_val=graph_dataset_val_solar, dataset_test=graph_dataset_test_solar,
    batch_size=params_solar["batch_size"], return_attention=False,
    reconcile=True, top_level_model='xgb',
    model_kwargs={'lr': params_solar["lr"], 'num_epochs': 300}, lam_reg=0,
)
pred_model_test_solar, target_test_solar, edge_index, attention_weights_solar = trainer_solar.train(
    plot_loss=True, force_training=True, save=True, patience=75   # cache like load
)
report('Solar (national)', pred_model_test_solar.sum(0), target_test_solar.sum(0))
# Out:
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train        134.50 8524662272.00       8.08
# val          261.68 16120030208.00      11.42
# test         382.33 16597041152.00      14.34
# Training model...
#  37%|███▋      | 111/300 [00:52<01:29,  2.12it/s]
# Early stopping at epoch 111
# Solar (national)             RMSE=     401  MAE=     227  nRMSE= 28.99%  sMAPE=107.92%

# %% [markdown]
# ## Combine the components into net-load
#
# The net-load truth is rebuilt from the **same** decomposition (rather than borrowing
# `target_test` from Part 1) and checked against the direct target.

# %%
# net-load = load - wind - solar  (per node, per half-hour)
pred_model_test_all = pred_model_test_load - pred_model_test_wind - pred_model_test_solar
target_test_all     = target_test_load - target_test_wind - target_test_solar

# Sanity: decomposed truth should equal the direct NetLoad target.
if 'target_test' in dir():
    _gap = rmse_np(target_test_all.sum(0), target_test.sum(0))
    print(f"[check] |decomposed truth - direct NetLoad truth| national RMSE = {_gap:.1f} MW "
          f"(~0 if NetLoad == Load - Wind - Solar in the data)")
# Out:
# [check] |decomposed truth - direct NetLoad truth| national RMSE = 0.0 MW (~0 if NetLoad == Load - Wind - Solar in the data)

# %%
plot_nodes(true=target_test_all, pred=pred_model_test_all, graph_dataset=graph_dataset_test_load)

# %% [markdown]
# ## Direct vs decomposed : honest comparison
#
# National **and** per-region. Net-load can cross zero per region, so regions are
# ranked by RMSE, not MAPE.

# %%
y_net = target_test_all.sum(0)                       # national net-load truth [T]
print("National net-load:")
report('  Direct (1 GNN)',                  pred_model_test.sum(0),     y_net)
report('  Decomposed (load - wind - solar)',pred_model_test_all.sum(0), y_net)

nodes = graph_dataset_test_load.nodes
print(f"\n{'Region':<24} {'Direct RMSE':>12} {'Decomp RMSE':>12}   winner")
print('-' * 66)
_wins = {'direct': 0, 'decomp': 0}
for i, r in enumerate(nodes):
    rd = rmse_np(pred_model_test[i],     target_test_all[i])
    rc = rmse_np(pred_model_test_all[i], target_test_all[i])
    win = 'direct' if rd < rc else 'decomp'
    _wins[win] += 1
    print(f"{r:<24} {rd:>12.0f} {rc:>12.0f}   {win}")
print(f"\nRegion wins: direct: {_wins['direct']}, decomposed: {_wins['decomp']}")
# Out:
# National net-load:
#   Direct (1 GNN)             RMSE=    2051  MAE=    1566  nRMSE=  4.24%  sMAPE=  3.36%
#   Decomposed (load - wind - solar) RMSE=    1867  MAE=    1365  nRMSE=  3.86%  sMAPE=  2.90%
#
# Region                    Direct RMSE  Decomp RMSE   winner
# ------------------------------------------------------------------
# auvergne_rhone_alpes              258          200   decomp
# bourgogne_franche_comte           153          141   decomp
# bretagne                          174          158   decomp
# centre_val_de_loire               196          189   decomp
# grand_est                         543          538   decomp
# haut_de_france                    686          653   decomp
# ile_de_france                     276          203   decomp
# normandie                         165          154   decomp
# nouvelle_aquitaine                261          239   decomp
# occitanie                         293          300   direct
# ...

# %% [markdown]
# # Part 3 : Reconciling the two approaches (online MLpol)
#
# Rather than *choosing* direct vs decomposed, treat them as two experts for net-load
# and let **MLpol** learn a data-adaptive, time-varying combination per node, updated
# each daily block. This is the compositional analogue of the spatial bottom-up
# reconciliation and can exploit periods/regions where one approach dominates
# (e.g. decomposition in sunny months, direct in winter) instead of committing to one.

# %%
from opera import Mixture

step = out_channels
T = target_test_all.shape[1]

def _reconcile_node(experts_cols, y_node):
    df = pd.DataFrame(experts_cols)
    n = df.shape[1]
    pred = np.empty(T)
    with np.errstate(all='ignore'):
        pred[:step] = df.iloc[:step].values @ (np.ones(n) / n)
    mix = Mixture(y=y_node[:step], experts=df.iloc[:step], model='MLpol', loss_type='mse')
    for s in range(step, T, step):
        e = min(s + step, T)
        pred[s:e] = np.ravel(mix.predict(new_experts=df.iloc[s:e]))[:e - s]
        mix.update(new_experts=df.iloc[s:e], new_y=y_node[s:e])
    return pred, np.asarray(mix.weights)[-1]

N = target_test_all.shape[0]
recon_nodes = np.empty((N, T))
final_w = []
for i in range(N):
    cols = {'direct': _to_np(pred_model_test[i])[:T],
            'decomp': _to_np(pred_model_test_all[i])[:T]}
    recon_nodes[i], w = _reconcile_node(cols, _to_np(target_test_all[i])[:T])
    final_w.append(w)
recon_national = recon_nodes.sum(0)

y_net = _to_np(target_test_all.sum(0))[:T]
print("National net-load : reconciliation vs the two approaches:")
report('  Direct',             _to_np(pred_model_test.sum(0))[:T],     y_net)
report('  Decomposed',         _to_np(pred_model_test_all.sum(0))[:T], y_net)
report('  Reconciled (MLpol)', recon_national,                         y_net)

final_w = np.array(final_w)
print("\nFinal MLpol weight on the *direct* expert, per region:")
for r, w in zip(nodes, final_w[:, 0]):
    print(f"  {r:<24} direct={w:4.2f}  decomp={1 - w:4.2f}")
# Out:
# National net-load : reconciliation vs the two approaches:
#   Direct                     RMSE=    2051  MAE=    1566  nRMSE=  4.24%  sMAPE=  3.36%
#   Decomposed                 RMSE=    1867  MAE=    1365  nRMSE=  3.86%  sMAPE=  2.90%
#   Reconciled (MLpol)         RMSE=    1833  MAE=    1354  nRMSE=  3.78%  sMAPE=  2.88%
#
# Final MLpol weight on the *direct* expert, per region:
#   auvergne_rhone_alpes     direct=0.13  decomp=0.87
#   bourgogne_franche_comte  direct=1.00  decomp=0.00
#   bretagne                 direct=0.00  decomp=1.00
#   centre_val_de_loire      direct=1.00  decomp=0.00
#   grand_est                direct=1.00  decomp=0.00
#   haut_de_france           direct=0.00  decomp=1.00
#   ile_de_france            direct=0.06  decomp=0.94
#   normandie                direct=0.47  decomp=0.53
#   nouvelle_aquitaine       direct=0.23  decomp=0.77
#   occitanie                direct=0.42  decomp=0.58
#   paca                     direct=0.34  decomp=0.66
# ...

# %% [markdown]
# # Part 4 : Hyperparameter optimization (Optuna)
#
# The GraphToolbox optimization module wraps Optuna. Set `OPTIMIZE = True`, pick a
# convolution and the dataset pair (direct, or one of the component datasets from
# Part 2), and run. Best params are saved to `./results_optim_{conv}/myGNN_best.json`
# and picked up automatically by the benchmark in Part 5.

# %%
OPTIMIZE = False

optim_base = {
    'num_layers': (1, 5),
    'hidden_channels': (32, 512),
    'lr': (1e-5, 1e-1),
}
_with_heads = optim_base | {'heads': (1, 5)}
_with_K     = optim_base | {'K': (1, 10)}

optim_kwargs_conv = {
    'GCNConv': optim_base, 'ChebConv': _with_K, 'SGConv': _with_K,
    'SSGConv': optim_base | {'alpha': (0.0, 1.0)}, 'LGConv': optim_base,
    'GCN2Conv': optim_base | {'alpha': (0.0, 1.0)}, 'ClusterGCNConv': optim_base, 'FAConv': optim_base,
    'GATConv': _with_heads, 'GATv2Conv': _with_heads, 'SuperGATConv': _with_heads,
    'TransformerConv': _with_heads, 'AGNNConv': optim_base,
    'DNAConv': optim_base | {'heads': (1, 5), 'K': (1, 10)},
    'SAGEConv': optim_base, 'GENConv': optim_base, 'GraphConv': optim_base, 'MFConv': optim_base,
    'LEConv': optim_base, 'SimpleConv': optim_base, 'EGConv': optim_base, 'GravNetConv': optim_base,
    'GINConv': optim_base, 'GINEConv': optim_base, 'NNConv': optim_base, 'ECConv': optim_base,
    'CGConv': optim_base, 'GMMConv': optim_base, 'GeneralConv': _with_heads, 'XConv': optim_base,
    'GatedGraphConv': optim_base, 'ARMAConv': optim_base, 'TAGConv': _with_K,
    'DirGNNConv': optim_base | {'alpha': (0.0, 1.0)},
    'AntiSymmetricConv': optim_base | {'gamma': (0.01, 1.0), 'epsilon': (0.01, 1.0)},
    'FiLMConv': optim_base, 'ResGatedGraphConv': optim_base, 'PDNConv': optim_base,
    'MixHopConv': optim_base, 'GPSConv': optim_base, 'FeaStConv': optim_base, 'PANConv': optim_base,
    'PNAConv': optim_base, 'EdgeConv': optim_base, 'DynamicEdgeConv': optim_base | {'k': (3, 15)},
    'RGCNConv': optim_base, 'RGATConv': _with_heads, 'FastRGCNConv': optim_base,
    'WLConv': optim_base, 'SignedConv': optim_base, 'APPNP': _with_K | {'alpha': (0.5, 1.0)},
}

if OPTIMIZE:
    conv_class = SuperGATConv
    optim_kwargs = optim_kwargs_conv[conv_class.__name__]
    optimizer = Optimizer(model=myGNN,
                          dataset_train=graph_dataset_train,   # swap for component datasets to tune those
                          dataset_val=graph_dataset_val,
                          conv_class=conv_class,
                          num_epochs=100,
                          optim_kwargs=optim_kwargs)
    optimizer.optimize(n_trials=200)

# %% [markdown]
# # Part 5 : Benchmark all convolutions (direct net-load)
#
# Trains a `myGNN` with shared defaults for every compatible PyG convolution on the
# **direct net-load** target; predictions are cached to disk. (Rerun on the component
# datasets to benchmark load/wind/solar separately.) Headline metric is **RMSE** —
# not MAPE.

# %%
import gc
import inspect
from torch_geometric.nn import conv as pyg_conv

_skip_keywords = ['CuGraph', 'GPSConv', 'Hetero', 'HAN', 'HGT', 'HEAT', 'Point', 'PPF', 'Hypergraph', 'Spline', 'XConv', 'WLConv']

ALL_CONV_CLASSES = {}
_x_probe = torch.randn(15, graph_dataset_train.num_node_features)
_ei_probe = torch.randint(0, 15, (2, 40))

for _name, _cls in inspect.getmembers(pyg_conv, inspect.isclass):
    if not _name.endswith('Conv'):
        continue
    if any(k in _name for k in _skip_keywords):
        continue
    try:
        _m = myGNN(in_channels=graph_dataset_train.num_node_features, hidden_channels=32,
                   out_channels=out_channels, num_layers=2, conv_class=_cls)
        with torch.no_grad():
            _out = _m(_x_probe, _ei_probe)
        if not torch.is_tensor(_out):
            raise ValueError
        del _m
        ALL_CONV_CLASSES[_name] = _cls
    except (ImportError, ModuleNotFoundError):
        pass
    except Exception:
        pass

del _x_probe, _ei_probe
print(f"Working convolutions ({len(ALL_CONV_CLASSES)}):")
for _n in ALL_CONV_CLASSES:
    print(f"  {_n}")
# Out:
# Working convolutions (47):
#   AGNNConv
#   ARMAConv
#   AntiSymmetricConv
#   CGConv
#   ChebConv
#   ClusterGCNConv
#   DNAConv
#   DirGNNConv
#   DynamicEdgeConv
#   ECConv
#   EGConv
#   EdgeConv
#   FAConv
#   FastRGCNConv
#   FeaStConv
#   FiLMConv
#   GATConv
#   GATv2Conv
#   GCN2Conv
#   GCNConv
#   GENConv
#   GINConv
#   GINEConv
#   GMMConv
#   GatedGraphConv
#   GeneralConv
#   GraphConv
#   GravNetConv
#   LEConv
#   LGConv
#   MFConv
#   MixHopConv
#   NNConv
#   PANConv
#   PDNConv
#   PNAConv
#   RGATConv
#   RGCNConv
#   ResGatedGraphConv
#   SAGEConv
#   SGConv
#   SSGConv
#   SignedConv
#   SimpleConv
#   SuperGATConv
#   TAGConv
#   TransformerConv
# ...

# %%
# Free Part 1-3 trainer/model objects before the 40+ model benchmark loop.
for _var in ['trainer', 'trainer_load', 'trainer_wind', 'trainer_solar',
             'model', 'model_load', 'model_wind', 'model_solar']:
    if _var in dir():
        exec(f'del {_var}')
gc.collect()

from inspect import signature as _sig, Parameter as _Param

_GNN_CTOR_PARAMS = {
    p.name for p in _sig(myGNN.__init__).parameters.values()
    if p.name not in ('self', 'in_channels', 'out_channels', 'conv_class', 'conv_kwargs')
    and p.kind not in (_Param.VAR_KEYWORD, _Param.VAR_POSITIONAL)
}
_SWEEP_LEVEL = {'num_layers', 'hidden_channels', 'lr', 'batch_size', 'adj_matrix'}

def _resolve_params(conv_name):
    json_path = f'./results_optim_{conv_name}/myGNN_best.json'
    if os.path.exists(json_path):
        with open(json_path) as _f:
            best = _json.load(_f)['params']
        source = 'optimized'
    else:
        best = {}
        source = 'default'
    run_params = {
        'num_layers':      int(best.get('num_layers',      LOOP_PARAMS['num_layers'])),
        'hidden_channels': int(best.get('hidden_channels', LOOP_PARAMS['hidden_channels'])),
        'lr':              float(best.get('lr',            LOOP_PARAMS['lr'])),
        'batch_size':      int(best.get('batch_size',      LOOP_PARAMS['batch_size'])),
        'adj_matrix':      best.get('adj_matrix',          LOOP_PARAMS['adj_matrix']),
        'num_epochs':      LOOP_PARAMS['num_epochs'],
        'patience':        LOOP_PARAMS['patience'],
    }
    model_kw = {k: v for k, v in best.items() if k in _GNN_CTOR_PARAMS and k not in _SWEEP_LEVEL}
    conv_kw  = {k: v for k, v in best.items() if k not in _GNN_CTOR_PARAMS and k not in _SWEEP_LEVEL}
    return run_params, model_kw, conv_kw, source

LOOP_PARAMS = {
    'num_layers': 2, 'hidden_channels': 64, 'lr': 1e-3, 'batch_size': 32,
    'adj_matrix': 'dtw', 'num_epochs': 100, 'patience': 30, 'reconcile': True,
}
RESULTS_DIR = './results_all_convolutions_netload'
os.makedirs(RESULTS_DIR, exist_ok=True)

_loop_state_path = os.path.join(RESULTS_DIR, '_loop_params.json')
_last_loop_params = None
if os.path.exists(_loop_state_path):
    with open(_loop_state_path) as _lf:
        _last_loop_params = _json.load(_lf)
_loop_params_unchanged = (_last_loop_params is None or _last_loop_params == LOOP_PARAMS)
with open(_loop_state_path, 'w') as _lf:
    _json.dump(LOOP_PARAMS, _lf)

trained_preds = {}
target_national = None
target_nodes = None
failed_loop = {}

_target_path       = os.path.join(RESULTS_DIR, 'target.pt')
_target_nodes_path = os.path.join(RESULTS_DIR, 'target_nodes.pt')
_current_adj = LOOP_PARAMS['adj_matrix']

for _ds in [graph_dataset_train, graph_dataset_val, graph_dataset_test]:
    _ds._set_adj_matrix(adj_matrix=_current_adj)

for conv_name, cls in ALL_CONV_CLASSES.items():
    pred_path = os.path.join(RESULTS_DIR, f'{conv_name}.pt')
    _params_path = os.path.join(RESULTS_DIR, f'{conv_name}_params.json')
    _params, _model_kw, _conv_kw, _src = _resolve_params(conv_name)
    _current_params_key = {**_params, **_model_kw, **_conv_kw, 'reconcile': LOOP_PARAMS['reconcile']}
    if os.path.exists(pred_path) and os.path.exists(_params_path):
        with open(_params_path) as _pf:
            _stored = _json.load(_pf)
        _cache_valid = (_stored == _current_params_key)
    else:
        _cache_valid = os.path.exists(pred_path) and _src == 'default' and _loop_params_unchanged
    if _cache_valid:
        trained_preds[conv_name] = torch.load(pred_path, weights_only=False)
        if target_national is None and os.path.exists(_target_path):
            target_national = torch.load(_target_path, weights_only=False)
        if target_nodes is None and os.path.exists(_target_nodes_path):
            target_nodes = torch.load(_target_nodes_path, weights_only=False)
        print(f'⏩ {conv_name:<25} loaded from cache  [{_src}]')
        continue

    print(f'\n🔄 Training {conv_name}... [{_src}]')
    seed_everything(42); gc.collect()
    if _params['adj_matrix'] != _current_adj:
        for _ds in [graph_dataset_train, graph_dataset_val, graph_dataset_test]:
            _ds._set_adj_matrix(adj_matrix=_params['adj_matrix'])
        _current_adj = _params['adj_matrix']
    _model = _trainer = None
    try:
        _model = myGNN(in_channels=graph_dataset_train.num_node_features,
                       num_layers=_params['num_layers'], hidden_channels=_params['hidden_channels'],
                       out_channels=out_channels, conv_class=cls, conv_kwargs=_conv_kw or None, **_model_kw)
        _trainer = Trainer(model=_model, dataset_train=graph_dataset_train,
                           dataset_val=graph_dataset_val, dataset_test=graph_dataset_test,
                           batch_size=_params['batch_size'],
                           model_kwargs={'lr': _params['lr'], 'num_epochs': _params['num_epochs']},
                           reconcile=LOOP_PARAMS['reconcile'], top_level_model='xgb', lam_reg=0)
        _result = _trainer.train(force_training=False, patience=_params['patience'])
        _pred, _target = _result[0], _result[1]
        torch.save(_pred, pred_path)
        with open(_params_path, 'w') as _pf:
            _json.dump(_current_params_key, _pf)
        trained_preds[conv_name] = _pred
        if target_national is None:
            target_national = _target.sum(dim=0).cpu()
            torch.save(target_national, _target_path)
            target_nodes = _target.cpu()
            torch.save(target_nodes, _target_nodes_path)
        _rmse = rmse_np(_pred.sum(dim=0), target_national)
        print(f'  ✅ RMSE national = {_rmse:.0f} MW  (nRMSE {nrmse_np(_pred.sum(dim=0), target_national):.2f}%)')
    except Exception as e:
        _msg = str(e).splitlines()[0] if str(e).strip() else type(e).__name__
        failed_loop[conv_name] = _msg
        print(f'  ❌ Failed: {_msg}')
    finally:
        del _trainer, _model
        gc.collect()

print(f'\n✅ Successfully trained / cached: {len(trained_preds)}')
if failed_loop:
    print(f'❌ Failed: {list(failed_loop.keys())}')
# Out:
# 🔄 Training AGNNConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train       1191.77       1.80       1.77
# val         2008.44       2.97       2.95
# test        2489.91       4.06       3.93
# Training model...
# 100%|██████████| 100/100 [00:58<00:00,  1.72it/s]
#   ✅ RMSE national = 2210 MW  (nRMSE 4.56%)
#
# 🔄 Training ARMAConv... [default]
# [Trainer] Fitting top-level model (xgb) for MinT reconciliation...
# [Trainer] Top-level xgb — national aggregate errors:
# split          RMSE      MAPE%      nMAE%
# -----------------------------------------
# train       1191.77       1.80       1.77
# val         2008.44       2.97       2.95
# test        2489.91       4.06       3.93
# Training model...
# 100%|██████████| 100/100 [00:46<00:00,  2.17it/s]
#   ✅ RMSE national = 2064 MW  (nRMSE 4.26%)
#
# ...

# %%
# Ranking by national RMSE (lower is better)
_scores = {n: rmse_np(p.sum(dim=0), target_national) for n, p in trained_preds.items()}
_names  = sorted(_scores, key=_scores.get)
_values = [_scores[n] for n in _names]
_has_hpo = [os.path.exists(f'./results_optim_{n}/myGNN_best.json') for n in _names]
_colors = ['#2ecc71' if h else '#3498db' for h in _has_hpo]

fig, ax = plt.subplots(figsize=(9, max(4, 0.35 * len(_names))))
bars = ax.barh(_names, _values, color=_colors, edgecolor='white', linewidth=0.4)
ax.bar_label(bars, fmt='%.0f', padding=3, fontsize=8)
ax.set_xlabel('RMSE national (MW)')
ax.set_title('Convolution benchmark — national net-load RMSE (lower is better)')
ax.invert_yaxis()
from matplotlib.patches import Patch
ax.legend(handles=[Patch(color='#2ecc71', label='HPO done'),
                   Patch(color='#3498db', label='Default params')], loc='lower right', fontsize=8)
plt.tight_layout(); plt.show(); plt.close(fig)

print(f'\n{"Rank":<5} {"Convolution":<25} {"RMSE":>10}  HPO')
print('-' * 50)
for _rank, _name in enumerate(_names, 1):
    _marker = '✅' if _has_hpo[_rank - 1] else '❌'
    print(f'{_rank:<5} {_name:<25} {_scores[_name]:>9.0f}  {_marker}')
# Out:
# Rank  Convolution                     RMSE  HPO
# --------------------------------------------------
# 1     RGATConv                       2000  ❌
# 2     GatedGraphConv                 2002  ❌
# 3     SuperGATConv                   2004  ❌
# 4     FiLMConv                       2005  ❌
# 5     PANConv                        2007  ❌
# 6     GMMConv                        2027  ❌
# 7     GCN2Conv                       2030  ❌
# 8     GATConv                        2032  ❌
# 9     FastRGCNConv                   2035  ❌
# 10    ResGatedGraphConv              2043  ❌
# 11    EGConv                         2045  ❌
# 12    ChebConv                       2046  ❌
# 13    RGCNConv                       2049  ❌
# 14    GATv2Conv                      2053  ❌
# 15    FeaStConv                      2054  ❌
# 16    GeneralConv                    2055  ❌
# 17    TransformerConv                2057  ❌
# 18    SAGEConv                       2058  ❌
# 19    SGConv                         2062  ❌
# ...

# %% [markdown]
# ## Mixture of Experts with Opera (national)
#
# MLpol online aggregation of the national net-load forecasts of all trained
# convolutions, with weights updated each daily block.

# %%
from opera import Mixture

assert target_national is not None, "Run the benchmark loop above first."
assert trained_preds, "No predictions available."

T    = len(target_national)
step = out_channels
y    = target_national.numpy().astype(float)

experts_data = {}
for name, preds in trained_preds.items():
    experts_data[name] = preds.sum(dim=0).cpu().detach().numpy()[:T]
experts_df = pd.DataFrame(experts_data)
bad_cols = experts_df.columns[~np.isfinite(experts_df.values).all(axis=0)].tolist()
if bad_cols:
    print(f"Dropping {len(bad_cols)} unstable expert(s): {bad_cols}")
    experts_df = experts_df.drop(columns=bad_cols)
print(f"Experts matrix: {experts_df.shape[1]} convolutions x {T} timesteps\n")

uniform_pred = experts_df.values.mean(axis=1)
report('Uniform average', uniform_pred, y)
best_name = min(experts_df.columns, key=lambda n: rmse_np(experts_df[n].values, y))
report(f'Best individual ({best_name})', experts_df[best_name].values, y)

n_experts = experts_df.shape[1]
predictions_opera = np.empty(T, dtype=float)
with np.errstate(all='ignore'):
    predictions_opera[:step] = experts_df.iloc[:step].values @ (np.ones(n_experts) / n_experts)
mixture = Mixture(y=y[:step], experts=experts_df.iloc[:step], model="MLpol", loss_type="mse")
for s in range(step, T, step):
    e = min(s + step, T)
    predictions_opera[s:e] = np.ravel(mixture.predict(new_experts=experts_df.iloc[s:e]))[:e - s]
    mixture.update(new_experts=experts_df.iloc[s:e], new_y=y[s:e])
report('Opera MLpol', predictions_opera, y)

final_weights = pd.Series(mixture.weights[-1], index=experts_df.columns).sort_values(ascending=False)
print("\nFinal expert weights (top 10):")
for name, w in final_weights.head(10).items():
    print(f"  {name:<30} {w:.4f}")
# Out:
# Experts matrix: 47 convolutions x 17472 timesteps
#
# Uniform average              RMSE=    1969  MAE=    1464  nRMSE=  4.07%  sMAPE=  3.15%
# Best individual (RGATConv)   RMSE=    2000  MAE=    1501  nRMSE=  4.13%  sMAPE=  3.23%
# Opera MLpol                  RMSE=    1957  MAE=    1446  nRMSE=  4.04%  sMAPE=  3.11%
#
# Final expert weights (top 10):
#   FiLMConv                       0.2974
#   GatedGraphConv                 0.2720
#   SuperGATConv                   0.1830
#   RGATConv                       0.1338
#   GENConv                        0.0983
#   EdgeConv                       0.0154
#   SimpleConv                     0.0000
#   TAGConv                        0.0000
#   GravNetConv                    0.0000
#   LEConv                         0.0000

# %%
# Monthly nRMSE + top expert weight trajectories
dates = pd.date_range(start=data_kwargs['day_inf_test'], periods=T, freq='30min')
months_idx = dates.to_period('M')
month_list = sorted(months_idx.unique())
month_short = [str(m)[-2:] for m in month_list]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))

opera_m, uniform_m, best_m = [], [], []
for month in month_list:
    mask = (months_idx == month)
    y_m = y[mask]
    opera_m.append(nrmse_np(predictions_opera[mask], y_m))
    uniform_m.append(nrmse_np(uniform_pred[mask], y_m))
    best_m.append(nrmse_np(experts_df[best_name].values[mask], y_m))

x = np.arange(len(month_list)); w = 0.25
ax1.bar(x - w, opera_m, w, label='Opera MLpol', color='steelblue')
ax1.bar(x,     uniform_m, w, label='Uniform avg', color='silver')
ax1.bar(x + w, best_m, w, label=best_name, color='salmon')
ax1.set_xticks(x); ax1.set_xticklabels(month_short)
ax1.set_xlabel('Month (2019)'); ax1.set_ylabel('nRMSE (%)')
ax1.set_title('Monthly national net-load nRMSE'); ax1.legend()

N_top = 8
top_experts = final_weights.head(N_top).index.tolist()
weights_mat = np.array(mixture.weights)
monthly_w = []
for month in month_list:
    last_t = int(np.where((months_idx == month))[0][-1])
    monthly_w.append(weights_mat[last_t])
weights_monthly_df = pd.DataFrame(np.array(monthly_w), columns=experts_df.columns, index=month_short)
for expert in top_experts:
    ax2.plot(month_short, weights_monthly_df[expert], marker='o', linewidth=1.8, label=expert)
ax2.set_xlabel('Month (2019)'); ax2.set_ylabel('Expert weight (MLpol)')
ax2.set_title(f'Top {N_top} expert weights over time')
ax2.legend(fontsize=8, bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout(); plt.show(); plt.close('all')

# %% [markdown]
# ## Expert pruning analysis
#
# MLpol concentrates mass on few experts. Identify the **survivors** a `GatedMultiConv`
# would need to emulate.

# %%
MEAN_THRESHOLD = 0.02
K_QUALITY = 8
K_DIVERSITY = 5

weights_mat = np.array(mixture.weights)
mean_weights = weights_mat.mean(axis=0)
max_weights = weights_mat.max(axis=0)
w_df = pd.DataFrame({'conv': experts_df.columns, 'mean_weight': mean_weights, 'max_weight': max_weights}
                    ).sort_values('mean_weight', ascending=False).reset_index(drop=True)
survivors = w_df[w_df['mean_weight'] > MEAN_THRESHOLD]['conv'].tolist()

_family = {
    'GatedGraphConv': 'recurrent', 'ResGatedGraphConv': 'recurrent', 'LEConv': 'edge-weighted',
    'GCNConv': 'spectral', 'GENConv': 'aggregation', 'SGConv': 'spectral', 'SAGEConv': 'aggregation',
    'GraphConv': 'aggregation', 'DNAConv': 'attention', 'SuperGATConv': 'attention', 'GCN2Conv': 'spectral',
    'SSGConv': 'spectral', 'TransformerConv': 'attention', 'PNAConv': 'aggregation', 'ARMAConv': 'spectral',
}
quality_set = w_df.head(K_QUALITY)['conv'].tolist()
diversity_set, seen_fam = [], set()
for _, row in w_df[w_df['mean_weight'] > MEAN_THRESHOLD].iterrows():
    fam = _family.get(row['conv'], row['conv'])
    if fam not in seen_fam:
        diversity_set.append(row['conv']); seen_fam.add(fam)
    if len(diversity_set) >= K_DIVERSITY:
        break

print(f'Threshold: mean weight > {MEAN_THRESHOLD:.0%}')
print(f'Survivors: {len(survivors)} / {len(experts_df.columns)} convolutions\n')
print(f'{"Rank":<5} {"Convolution":<30} {"Mean wt":>8} {"Family":<16}')
print('-' * 62)
for i, row in w_df.head(20).iterrows():
    fam = _family.get(row['conv'], '-')
    marker = 'A' if row['conv'] in quality_set else ('B' if row['conv'] in diversity_set else ' ')
    marker = 'AB' if row['conv'] in quality_set and row['conv'] in diversity_set else marker
    print(f"{i+1:<5} {row['conv']:<30} {row['mean_weight']:>8.4f} {fam:<16} {marker}")

def _mass(conv_list):
    cols = [list(experts_df.columns).index(c) for c in conv_list]
    return weights_mat[:, cols].sum(axis=1).mean()

print(f'\nOption A — top-{K_QUALITY} by weight:  mass {_mass(quality_set):.1%}')
print(f'  {quality_set}')
print(f'Option B — one-per-family (K={K_DIVERSITY}):  mass {_mass(diversity_set):.1%}')
print(f'  {diversity_set}')

fig, axes = plt.subplots(1, 2, figsize=(16, 5))
top20 = w_df.head(20)
def _color(name):
    if name in quality_set and name in diversity_set: return '#8e44ad'
    if name in quality_set: return '#e74c3c'
    if name in diversity_set: return '#2980b9'
    if name in survivors: return '#e67e22'
    return '#bdc3c7'
colors = [_color(c) for c in top20['conv']]
axes[0].barh(top20['conv'][::-1], top20['mean_weight'][::-1], color=colors[::-1])
axes[0].axvline(MEAN_THRESHOLD, color='black', linestyle='--', linewidth=1, label=f'threshold={MEAN_THRESHOLD:.0%}')
axes[0].set_xlabel('Time-averaged MLpol weight'); axes[0].set_title('Expert importance (top-20)')
from matplotlib.patches import Patch
axes[0].legend(handles=[Patch(color='#8e44ad', label='In both A+B'),
                        Patch(color='#e74c3c', label=f'Option A only (top-{K_QUALITY})'),
                        Patch(color='#2980b9', label=f'Option B only (diversity-{K_DIVERSITY})'),
                        Patch(color='#e67e22', label='Survivor only'),
                        Patch(color='#bdc3c7', label='Below threshold')], fontsize=7)
dates_w = pd.date_range(start=data_kwargs['day_inf_test'], periods=len(weights_mat), freq='30min')
for conv in quality_set:
    k_idx = list(experts_df.columns).index(conv)
    axes[1].plot(dates_w, weights_mat[:, k_idx], label=conv, linewidth=1.6,
                 linestyle='--' if conv not in diversity_set else '-')
axes[1].set_xlabel('Date (2019)'); axes[1].set_ylabel('MLpol weight')
axes[1].set_title(f'Option A top-{K_QUALITY} weight trajectories'); axes[1].tick_params(axis='x', rotation=30)
axes[1].legend(fontsize=8)
plt.tight_layout(); plt.show(); plt.close('all')
print(f'\nRECOMMENDED (Option A, K={K_QUALITY}): PRUNED_CONVS = {quality_set}')
# Out:
# Threshold: mean weight > 2%
# Survivors: 12 / 47 convolutions
#
# Rank  Convolution                     Mean wt Family
# --------------------------------------------------------------
# 1     GatedGraphConv                   0.1467 recurrent        AB
# 2     TransformerConv                  0.1360 attention        AB
# 3     SuperGATConv                     0.1094 attention        A
# 4     EGConv                           0.1060 -                AB
# 5     GATConv                          0.0986 -                AB
# 6     GENConv                          0.0948 aggregation      AB
# 7     FiLMConv                         0.0551 -                A
# 8     GMMConv                          0.0447 -                A
# 9     ResGatedGraphConv                0.0400 recurrent
# 10    RGATConv                         0.0363 -
# 11    EdgeConv                         0.0249 -
# 12    PNAConv                          0.0210 aggregation
# 13    DynamicEdgeConv                  0.0196 -
# ...

# %% [markdown]
# ## Opera bottom-up aggregation
#
# Run MLpol **independently per node**, then sum — strictly more expressive than
# top-level aggregation since regions can favour different experts.

# %%
from opera import Mixture

assert target_nodes is not None, "Run the benchmark loop first (target_nodes saved)."

T = len(target_national)
step = out_channels
y_global = target_national.numpy().astype(float)
_valid_names = [n for n in trained_preds if n not in (bad_cols if 'bad_cols' in dir() else [])]
N_nodes = target_nodes.shape[0]
print(f"Running per-node Opera MLpol ({N_nodes} nodes x {len(_valid_names)} experts)...")

node_opera_preds = []
for node_idx in range(N_nodes):
    y_node = target_nodes[node_idx].numpy().astype(float)
    node_experts = {name: trained_preds[name][node_idx].cpu().detach().numpy()[:T] for name in _valid_names}
    node_df = pd.DataFrame(node_experts)
    bad_node = node_df.columns[~np.isfinite(node_df.values).all(axis=0)].tolist()
    if bad_node:
        node_df = node_df.drop(columns=bad_node)
    n_exp = node_df.shape[1]
    node_pred = np.empty(T, dtype=float)
    with np.errstate(all='ignore'):
        node_pred[:step] = node_df.iloc[:step].values @ (np.ones(n_exp) / n_exp)
    mix_node = Mixture(y=y_node[:step], experts=node_df.iloc[:step], model="MLpol", loss_type="mse")
    for s in range(step, T, step):
        e = min(s + step, T)
        node_pred[s:e] = np.ravel(mix_node.predict(new_experts=node_df.iloc[s:e]))[:e - s]
        mix_node.update(new_experts=node_df.iloc[s:e], new_y=y_node[s:e])
    node_opera_preds.append(node_pred)

node_opera_preds = np.stack(node_opera_preds, axis=0)
predictions_opera_bu = node_opera_preds.sum(axis=0)

print()
report("Opera MLpol (top-level)", predictions_opera, y_global)
report("Opera MLpol (bottom-up)", predictions_opera_bu, y_global)
report("Uniform average",         uniform_pred, y_global)
report(f"Best individual ({best_name})", experts_df[best_name].values, y_global)
# Out:
# Running per-node Opera MLpol (12 nodes x 47 experts)...
#
# Opera MLpol (top-level)      RMSE=    1957  MAE=    1446  nRMSE=  4.04%  sMAPE=  3.11%
# Opera MLpol (bottom-up)      RMSE=    1940  MAE=    1440  nRMSE=  4.01%  sMAPE=  3.09%
# Uniform average              RMSE=    1969  MAE=    1464  nRMSE=  4.07%  sMAPE=  3.15%
# Best individual (RGATConv)   RMSE=    2000  MAE=    1501  nRMSE=  4.13%  sMAPE=  3.23%

# %% [markdown]
# ## Per-region error map
#
# Each region coloured by **nRMSE** (RMSE normalised by its mean |net-load|), since
# net-load per region can be small / change sign — MAPE would be unstable.

# %%
nodes
# Out:
# array(['auvergne_rhone_alpes', 'bourgogne_franche_comte', 'bretagne',
#        'centre_val_de_loire', 'grand_est', 'haut_de_france',
#        'ile_de_france', 'normandie', 'nouvelle_aquitaine', 'occitanie',
#        'paca', 'pays_de_loire'], dtype=object)

# %%
from graphtoolbox.utils.visualizations import plot_node_errors_map
from graphtoolbox.utils.helper_functions import load_kwargs

assert target_nodes is not None, "Run the benchmark loop first."
T_map = target_nodes.shape[1]
true_np = target_nodes.numpy()
nodes = graph_dataset_train.nodes

def _node_nrmse(pred_np, true_np):
    denom = np.abs(true_np).mean(axis=1, keepdims=True).clip(min=1e-6)
    rmse = np.sqrt(np.mean((pred_np - true_np) ** 2, axis=1, keepdims=True))
    return (100 * rmse / denom).ravel()

node_errors = {}
_best_np = trained_preds[best_name].cpu().detach().numpy()[:, :T_map]
node_errors[f'Best model\n({best_name})'] = _node_nrmse(_best_np, true_np)
if 'node_opera_preds' in dir() and node_opera_preds is not None:
    node_errors['Opera MLpol\n(bottom-up)'] = _node_nrmse(node_opera_preds[:, :T_map], true_np)

plot_node_errors_map(
    node_errors=node_errors, nodes=nodes,
    df_pos=load_kwargs(folder_config=graph_dataset_train.folder_config, kwargs='df_pos'),
    metric_label='nRMSE (%)', cmap='RdYlGn_r',
)

# %% [markdown]
# ## Error diagnostics
#
# Signed bias (MW) and nRMSE (%) of the net-load error by half-hour of day, day of
# week, and month — to see *when* the model struggles. With the decomposition you can
# repeat this per component to attribute net-load error to load vs wind vs solar.

# %%
import matplotlib.ticker as mticker

DIAG_NODES = ['haut_de_france', 'ile_de_france']

for DIAG_NODE in DIAG_NODES:
    if DIAG_NODE not in list(nodes):
        print(f"(skip {DIAG_NODE}: not in node list)"); continue
    ni = list(nodes).index(DIAG_NODE)
    T = target_nodes.shape[1]
    true = target_nodes[ni].numpy().astype(float)

    preds_diag = {f'Best ({best_name})': trained_preds[best_name][ni].cpu().detach().numpy()[:T]}
    if 'node_opera_preds' in dir() and node_opera_preds is not None:
        preds_diag['Opera BU'] = node_opera_preds[ni, :T]

    dates = pd.Series(pd.date_range(start=data_kwargs['day_inf_test'], periods=T, freq='30min'))
    instants = dates.dt.hour * 2 + dates.dt.minute // 30
    dow = dates.dt.dayofweek
    months = dates.dt.month

    DOW_LABELS = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
    MONTH_LABELS = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    INST_LABELS = [f'{h:02d}:{m:02d}' for h in range(24) for m in (0, 30)]
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:len(preds_diag)]

    fig, axes = plt.subplots(2, 3, figsize=(16, 8))
    fig.suptitle(f'Error diagnostics: {DIAG_NODE.replace("_", " ")}', fontsize=14, fontweight='bold')
    groups = [
        (instants, np.arange(48), INST_LABELS, 'Half-hour of day'),
        (dow,      np.arange(7),  DOW_LABELS,  'Day of week'),
        (months-1, np.arange(12), MONTH_LABELS,'Month'),
    ]
    for col, (idx, bins, labels, xlabel) in enumerate(groups):
        ax_bias, ax_err = axes[0, col], axes[1, col]
        bar_w = 0.8 / max(len(preds_diag), 1)
        offsets = np.linspace(-0.4 + bar_w/2, 0.4 - bar_w/2, len(preds_diag))
        for (name, pred), color, offset in zip(preds_diag.items(), colors, offsets):
            err = pred - true
            bias = np.array([err[idx == b].mean() if (idx == b).any() else np.nan for b in bins])
            nrmse_b = np.array([
                100 * np.sqrt(np.mean(err[idx == b] ** 2)) / (np.abs(true[idx == b]).mean() + 1e-6)
                if (idx == b).any() else np.nan for b in bins])
            x = bins + offset
            ax_bias.bar(x, bias, width=bar_w * 0.9, color=color, alpha=0.75, label=name)
            ax_err.bar(x, nrmse_b, width=bar_w * 0.9, color=color, alpha=0.75, label=name)
        for ax, ylabel, title in [(ax_bias, 'Bias (MW)', 'Signed bias'), (ax_err, 'nRMSE (%)', 'nRMSE')]:
            ax.axhline(0, color='black', linewidth=0.7, linestyle='--')
            ax.set_xticks(bins)
            if len(labels) == 48:
                ax.set_xticklabels([l if i % 4 == 0 else '' for i, l in enumerate(labels)], rotation=45, ha='right', fontsize=7)
            else:
                ax.set_xticklabels(labels, fontsize=9)
            ax.set_ylabel(ylabel, fontsize=9); ax.set_title(f'{title} by {xlabel}', fontsize=10)
            ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda v, _: f'{v:,.1f}'))
            if col == 0:
                ax.legend(fontsize=8, loc='upper left')
    plt.tight_layout(); plt.show(); plt.close(fig)
